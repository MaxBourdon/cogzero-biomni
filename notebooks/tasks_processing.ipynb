# %%
import os
import sys
# Use local biomni
sys.path.insert(0, "/home/runai-home/Biomni/")

# %%
from pathlib import Path
from collections import defaultdict
from difflib import SequenceMatcher

# %%
from biomni.cogzero.canonicalizer import canonicalize_output, compare_outputs
from biomni.cogzero.utils import load_data, save_data
from biomni.cogzero.nb_utils import *

# %%
ver = "v0"
tasks_dir = Path(f"/mlbio_scratch/kodryan/Biomni/data/generated/tasks/{ver}")
raw_tasks_dir = tasks_dir / "raw"
all_tasks_dict = load_data_dict(raw_tasks_dir)

# %%
clean_tasks = []

for trial, tasks in all_tasks_dict.items():
    print(f"{trial}:\t{len(tasks)} tasks")
    for task in tasks:
        clean_tasks.append(task)

print(25 * '-')
print(f"Total:  \t{len(clean_tasks)} tasks")
# Out:
# trial_0:	21 tasks
# trial_1:	20 tasks
# trial_2:	20 tasks
# trial_3:	21 tasks
# trial_4:	21 tasks
# trial_5:	21 tasks
# trial_6:	21 tasks
# trial_7:	21 tasks
# trial_8:	21 tasks
# trial_9:	21 tasks
# trial_10:	21 tasks
# trial_11:	21 tasks
# trial_12:	21 tasks
# trial_13:	21 tasks
# trial_14:	21 tasks
# trial_15:	21 tasks
# -------------------------
# Total:  	334 tasks

# %%
def get_tasks_by_gta(task_list: list[dict[str, str]], sim_thresh=0.9) -> dict[str, list[dict[str, str]]]:
    """
    Bin tasks by ground-truth answers.
    Tasks with similar answers end up in the same bin.
    """
    tasks_by_gta = defaultdict(list)

    for task in task_list:
        task_gta = task["ground_truth_answer"]
        task_key = canonicalize_output(task_gta.lower())
        sm = SequenceMatcher(a=task_key)
        
        bin_key = task_key
        for key in tasks_by_gta:
            sm.set_seq2(key)
            if sm.ratio() > sim_thresh:
                bin_key = key
                break
                
        tasks_by_gta[bin_key].append(task)

    return tasks_by_gta

# %%
tasks_by_gta = get_tasks_by_gta(clean_tasks)

# %%
nonsingle_keys = []

for gta_key, tasks in tasks_by_gta.items():
    n_tasks = len(tasks)
    print(f"{gta_key:100}{n_tasks} tasks")
    if n_tasks > 1:
        nonsingle_keys.append(gta_key)
# Out:
# nonmalignant                                                                                        1 tasks
# nb_7767_3495_reg1                                                                                   1 tasks
# paep                                                                                                2 tasks
# lymphocyte                                                                                          5 tasks
# natural_killer_cell                                                                                 1 tasks
# monocyte                                                                                            2 tasks
# 3357                                                                                                3 tasks
# ensg00000286009                                                                                     1 tasks
# gabaergic neuron                                                                                    1 tasks
# hoxd13                                                                                              1 tasks
# cd4.memory                                                                                          1 tasks
# 15-20                                                                                               1 tasks
# ac022414.1                                                                                          1 tasks
# nmj accessory                                                                                       5 tasks
# mf-i                                                                                                3 tasks
# goblet cell                                                                                         6 tasks
# b_cell                                                                                              3 tasks
# r24_p2538                                                                                           2 tasks
# csf3                                                                                                1 tasks
# uba52                                                                                               1 tasks
# tom_vct                                                                                             2 tasks
# hepatocyte                                                                                          2 tasks
# 5                                                                                                   2 tasks
# 4                                                                                                   3 tasks
# cardiac_endothelial_cell                                                                            1 tasks
# rap1gap2                                                                                            1 tasks
# control                                                                                             9 tasks
# 3427                                                                                                2 tasks
# l5 extratelencephalic projecting glutamatergic cortical neuron                                      1 tasks
# chondroprog::wholelimb                                                                              1 tasks
# naive.bcells.isghi                                                                                  1 tasks
# xist                                                                                                5 tasks
# myh1+myh7+                                                                                          1 tasks
# b-lymphocytes                                                                                       3 tasks
# alzheimer disease                                                                                   2 tasks
# cl:2000060                                                                                          1 tasks
# interferon-response                                                                                 2 tasks
# csh1                                                                                                2 tasks
# cyp11b2                                                                                             1 tasks
# anbl12p1-like chemotherapy                                                                          5 tasks
# mt-co3                                                                                              3 tasks
# plasma cell                                                                                         1 tasks
# naaladl2                                                                                            1 tasks
# 69.5100                                                                                             1 tasks
# arhgap24                                                                                            1 tasks
# macro                                                                                               1 tasks
# mono.il1b+                                                                                          1 tasks
# 464c                                                                                                2 tasks
# nuclei                                                                                              2 tasks
# mf-isn(fg)                                                                                          5 tasks
# cells                                                                                               1 tasks
# 9                                                                                                   6 tasks
# b cell                                                                                              4 tasks
# 1.2370                                                                                              1 tasks
# scdonor_tg1_mother                                                                                  1 tasks
# tchh                                                                                                1 tasks
# chp667                                                                                              1 tasks
# 13                                                                                                  2 tasks
# pkhd1l1+ ec                                                                                         1 tasks
# cd4t_cm                                                                                             1 tasks
# endothelial_cell                                                                                    4 tasks
# adipocyte of omentum tissue                                                                         4 tasks
# grin2a                                                                                              2 tasks
# wholelimb                                                                                           1 tasks
# caecum                                                                                              2 tasks
# 35-40                                                                                               1 tasks
# glis3-as1                                                                                           1 tasks
# astrocyte                                                                                           1 tasks
# hofbauer cell                                                                                       1 tasks
# 6720483e21rik                                                                                       3 tasks
# evt_late_3                                                                                          5 tasks
# cortical cell of adrenal gland                                                                      1 tasks
# chp667, inc doxorubicin                                                                             1 tasks
# cardiac_neuron                                                                                      2 tasks
# cxcl9                                                                                               1 tasks
# b cell::3350                                                                                        1 tasks
# 1                                                                                                   1 tasks
# in-mge-pv                                                                                           1 tasks
# primitive red blood cell                                                                            1 tasks
# mesenteric lymph node                                                                               3 tasks
# tnfrsf12a+muscs                                                                                     3 tasks
# rpl10                                                                                               1 tasks
# 500c                                                                                                2 tasks
# granulosa_cell                                                                                      1 tasks
# r24_p2324                                                                                           1 tasks
# lm                                                                                                  1 tasks
# 8                                                                                                   5 tasks
# 14                                                                                                  3 tasks
# 3                                                                                                   3 tasks
# 20                                                                                                  2 tasks
# central memory cd4-positive, alpha-beta t cell                                                      2 tasks
# fp236383.1                                                                                          2 tasks
# 3384                                                                                                1 tasks
# en-l2_3-it                                                                                          1 tasks
# mes3                                                                                                1 tasks
# young                                                                                               2 tasks
# mf-iisc(fg)                                                                                         2 tasks
# tg                                                                                                  5 tasks
# syncytiotrophoblast cell                                                                            2 tasks
# adrn-calcium                                                                                        1 tasks
# anbl 09p1                                                                                           2 tasks
# kcne1                                                                                               1 tasks
# va8                                                                                                 1 tasks
# progenitor                                                                                          1 tasks
# hoxa10                                                                                              1 tasks
# ilc3s.rorgt+                                                                                        1 tasks
# tnfrsf12a_plus_muscs                                                                                1 tasks
# mesothelium                                                                                         1 tasks
# mf_typei(cytoplasmic)                                                                               2 tasks
# nmj                                                                                                 1 tasks
# r24_p2392::oligodendrocyte                                                                          1 tasks
# ralyl                                                                                               1 tasks
# cxcl10                                                                                              1 tasks
# va1                                                                                                 1 tasks
# first_trimester                                                                                     1 tasks
# 5386stdy7537944                                                                                     1 tasks
# rps4y1                                                                                              1 tasks
# adipocyte                                                                                           1 tasks
# myh2+myh7+                                                                                          2 tasks
# 70-75                                                                                               1 tasks
# oocyte                                                                                              1 tasks
# pcdh9                                                                                               1 tasks
# extravillous trophoblast                                                                            1 tasks
# kidney cell                                                                                         1 tasks
# 2                                                                                                   2 tasks
# anbl0532-like therapy with cisplatin & etoposide                                                    2 tasks
# cpa3                                                                                                1 tasks
# cytotoxic t cell                                                                                    1 tasks
# 3313                                                                                                2 tasks
# oligodendrocyte                                                                                     1 tasks
# neuron                                                                                              2 tasks
# cd3g                                                                                                1 tasks
# mf_typeii(fg)                                                                                       1 tasks
# hyb                                                                                                 1 tasks
# stem_cell                                                                                           1 tasks
# stroma a                                                                                            1 tasks
# inhibitory interneuron                                                                              1 tasks
# pooled_deprived_p7                                                                                  1 tasks
# synj2bp-cox16                                                                                       1 tasks
# mural_cell                                                                                          1 tasks
# mis-c                                                                                               3 tasks
# mo_cd16                                                                                             1 tasks
# 3382                                                                                                1 tasks
# adh+fibro                                                                                           2 tasks
# b cell zone reticular cell                                                                          1 tasks
# myeov                                                                                               1 tasks
# cd16-nk                                                                                             1 tasks
# mature_enterocyte                                                                                   1 tasks
# gpr141                                                                                              1 tasks
# pf                                                                                                  3 tasks
# g1/m phase early                                                                                    1 tasks
# neuroblast (sensu vertebrata)                                                                       1 tasks
# zic2                                                                                                1 tasks
# mcm8-as1                                                                                            1 tasks
# l4 intratelencephalic projecting glutamatergic neuron                                               1 tasks
# rdh10+distalmes                                                                                     1 tasks
# cd36                                                                                                1 tasks
# 25-30                                                                                               1 tasks
# 20-25                                                                                               1 tasks
# luzp4                                                                                               1 tasks
# ighg1                                                                                               1 tasks
# hofbauer cell::tg                                                                                   1 tasks
# cxcl8                                                                                               1 tasks
# primary tumor resection + laparotomy post 3 cycles of induction chemo per anbl12p1                  1 tasks
# mybpc3                                                                                              1 tasks
# effector memory cd8-positive, alpha-beta t cell                                                     1 tasks
# 3431                                                                                                1 tasks
# nrgn::glutamatergic neuron                                                                          1 tasks
# transmes                                                                                            1 tasks
# fos                                                                                                 1 tasks
# myh1+myh2+myh7+                                                                                     2 tasks
# 25                                                                                                  1 tasks
# 11                                                                                                  2 tasks
# slfn14                                                                                              1 tasks
# zfp36                                                                                               1 tasks
# fibroblast                                                                                          2 tasks
# mt3                                                                                                 1 tasks
# mp_lyve1lo/mhcii_hi                                                                                 1 tasks
# t cell                                                                                              1 tasks
# ark35::0.0314                                                                                       1 tasks
# small intestine peyer's patch                                                                       3 tasks
# b-plasma                                                                                            1 tasks
# pericyte::pick disease                                                                              1 tasks
# 15                                                                                                  1 tasks
# anbl12p1-like                                                                                       1 tasks
# myocarditis                                                                                         1 tasks
# mis-c::t_prolif                                                                                     1 tasks
# anxa1                                                                                               1 tasks
# mes1::wholelimb                                                                                     1 tasks
# cd74::dc.il1b_high.cd103+                                                                           1 tasks
# zfand5                                                                                              1 tasks
# specialised_mf_populations                                                                          1 tasks
# mf_type-myh8+                                                                                       2 tasks
# phagocyte                                                                                           1 tasks
# r24_p2392                                                                                           1 tasks
# srcin1                                                                                              1 tasks
# 6                                                                                                   1 tasks
# malat1                                                                                              1 tasks
# unknown                                                                                             1 tasks
# 5478stdy7935101                                                                                     1 tasks
# tenocyte                                                                                            1 tasks
# 26                                                                                                  1 tasks
# r24_p2730                                                                                           1 tasks
# sct                                                                                                 1 tasks
# nrg1                                                                                                1 tasks
# ch_18                                                                                               1 tasks
# 3350::9                                                                                             1 tasks
# 147                                                                                                 1 tasks
# thigh                                                                                               1 tasks
# rbc                                                                                                 1 tasks
# pericyte                                                                                            1 tasks
# microglial cell                                                                                     1 tasks

# %%
print(f"All keys: {len(tasks_by_gta)} \t nonsingle keys: {len(nonsingle_keys)}")
print(f"All tasks: {sum(len(tasks) for tasks in tasks_by_gta.values())} \t \
nonsingle tasks: {sum(len(tasks) for key, tasks in tasks_by_gta.items() if key in nonsingle_keys)}")
# Out:
# All keys: 212 	 nonsingle keys: 63
# All tasks: 334 	 nonsingle tasks: 185

# %%
for gta_key in nonsingle_keys:
    tasks = tasks_by_gta[gta_key]
    print(f"Group {gta_key}")
    print(100 * '-')
    for tid, task in enumerate(tasks):
        print(f"Task {tid}")
        print(f"Dataset path: {task['dataset_path']}")
        print(f"Description: {task['task_description']}")
        print(f"Answer: {task['ground_truth_answer']}")
        print()
# Out:
# Group paep
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# Description: In the snRNA-seq dataset of macrophages from high‑risk neuroblastoma before (DX) and after (PTX) chemotherapy, identify the gene that shows the strongest statistically significant up‑regulation (largest positive log₂ fold‑change, FDR < 0.05) in post‑treatment macrophages compared to diagnostic macrophages. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: PAEP
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# Description: Within the macrophage nuclei, identify the gene that shows the strongest statistically significant up‑regulation (largest positive log2‑fold‑change, adjusted p‑value < 0.05) in the PTX stage compared to the DX stage. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: PAEP
#
# Group lymphocyte
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# Description: From the provided single‑cell RNA‑seq dataset, identify which cell type shows the greatest enrichment in the MIS-C condition relative to the Control condition when comparing cell‑type proportions (MIS-C proportion divided by Control proportion). Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: lymphocyte
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# Description: Using the provided single‑cell dataset, compute the proportion of each cell type within the Control group and within all disease groups combined (any Condition not equal to 'Control'). Calculate the log2 fold‑change of disease proportion over control proportion for each cell type (add a pseudocount of 1e-6 to avoid division by zero). Identify the cell type with the highest log2 fold‑change. Answer format: a single cell‑type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: lymphocyte
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# Description: Compute the proportion of each cell type (from the 'cell_type' column) within each condition in the dataset. Then calculate the fold‑change of the proportion in the 'MIS-C' condition relative to the 'Control' condition (MIS-C proportion divided by Control proportion). Identify the cell type with the highest fold‑change. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (case‑sensitive, shape: label).
# Answer: lymphocyte
#
# Task 3
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# Description: Using the provided AnnData object, compute for each cell type the proportion of cells belonging to the disease 'myocarditis' and the proportion belonging to 'healthy'. Calculate the log2 fold‑change of these proportions (log2(prop_myocarditis / prop_healthy)) for each cell type. Identify the cell type with the highest positive log2 fold‑change (i.e., the strongest enrichment in myocarditis relative to healthy). Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: lymphocyte
#
# Task 4
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# Description: Using the provided single‑cell RNA‑seq dataset of human cardiac tissue, compute the proportion of each annotated cell type within the two disease conditions ('healthy' and 'myocarditis'). Identify the cell type whose proportion shows the greatest positive log2 fold‑change (myocarditis vs healthy). Answer format: a single cell‑type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: lymphocyte
#
# Group monocyte
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Identify the cell type that is most enriched in the MIS-C condition relative to the Control condition, using an odds ratio calculated from a 2 × 2 contingency table (add a 0.5 pseudocount to each cell to avoid division by zero). Answer format: a single lowercase label with underscores (shape: label).
# Answer: monocyte
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Using the provided AnnData object, calculate the proportion of cells labeled as 'MIS-C' within each coarse cell type found in the 'cell_type' column. Identify the cell type that has the highest proportion of MIS-C cells. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: monocyte
#
# Group 3357
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# Description: From the provided snRNA‑seq dataset of human visceral adipose tissue, compute for each donor (column 'donor_id') the proportion of nuclei annotated as "macrophage" in the 'cell_type' column. Identify the donor with the highest macrophage proportion. Answer format: a single donor identifier (shape: label).
# Answer: 3357
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# Description: Identify the donor (donor_id) that contributes the highest proportion of macrophage cells in the provided visceral adipose snRNA‑seq dataset. Answer format: a single donor identifier exactly as it appears in the donor_id column (shape: label).
# Answer: 3357
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# Description: Identify the donor (donor_id) that exhibits the highest proportion of cells annotated as "macrophage" among all donors in the provided single-nucleus RNA‑seq dataset. Answer format: a single donor ID string (shape: label).
# Answer: 3357
#
# Group nmj accessory
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Using the provided myonuclei single-nucleus RNA‑seq dataset, compute for each cell type in the 'annotation_level1' annotation the proportion of nuclei belonging to the 'old' age bin and the proportion belonging to the 'young' age bin. Add a pseudocount of 1 to the counts of each age bin for every cell type to avoid division‑by‑zero. Calculate the log2 enrichment as log2(old_proportion / young_proportion). Identify the cell type with the highest log2 enrichment (i.e., strongest relative enrichment in old nuclei). Answer format: a single label matching exactly one entry of the 'annotation_level1' column (case‑sensitive, including spaces).
# Answer: NMJ accessory
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Across the donor age groups present in the dataset, compute the proportion of cells belonging to each annotation_level1 cell type within each age group, then calculate the Spearman rank correlation between the numeric midpoint of the age group and the cell‑type proportion. Identify the cell type that shows the strongest positive monotonic trend (i.e., the highest Spearman rho). Answer format: a single cell‑type label exactly as it appears in the annotation_level1 column (shape: label).
# Answer: NMJ accessory
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: From the provided muscle nuclei single-nucleus RNA‑seq dataset, compute for each cell type (column 'annotation_level1') the proportion of cells belonging to the 'old' age bin (Age_bin == 'old'). Identify the cell type with the highest proportion of old cells. Answer format: a single label exactly matching the value in the 'annotation_level1' column (case‑sensitive, may contain spaces).
# Answer: NMJ accessory
#
# Task 3
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Using the provided myonuclei dataset, for each SampleID compute the proportion of nuclei belonging to each 'annotation_level1' cell type. Convert each sample's 'Age_group' (e.g., "15-20") to the numeric midpoint (e.g., 17.5). Calculate the Spearman rank correlation (ρ) between the cell‑type proportion and the numeric age midpoint across samples. Identify the cell type with the strongest positive age‑associated increase (largest positive ρ). Answer format: a single label exactly as it appears in the 'annotation_level1' column (shape: label).
# Answer: NMJ accessory
#
# Task 4
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Using the provided muscle nuclei dataset, compute for each cell type annotation (annotation_level1) the proportion of nuclei belonging to that annotation within each age group. Convert the age groups to numeric midpoints (15-20 → 17.5, 20-25 → 22.5, 25-30 → 27.5, 35-40 → 37.5, 55-60 → 57.5, 60-65 → 62.5, 70-75 → 72.5). For each annotation, calculate the Spearman correlation (ρ) between the numeric age and its proportion across the age groups. Identify the annotation with the highest positive Spearman ρ. Answer format: a single label exactly as it appears in the "annotation_level1" column (shape: label).
# Answer: NMJ accessory
#
# Group mf-i
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: From the AnnData file, calculate for each cell type in the column `annotation_level1` its proportion of cells within each batch (`batch` column, values 'cells' and 'nuclei'). Identify the cell type with the greatest absolute difference in proportion between the two batches. Provide the cell‑type label exactly as it appears in `annotation_level1`. Answer format: a single label (shape: label).
# Answer: MF-I
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_human_muscle_data.h5ad
# Description: Using the provided AnnData file, calculate the proportion of each annotation_level2 cell type within each assay batch (batch column, values cells and nuclei). Determine which cell type shows the greatest absolute difference in proportion between the two batches. Report the exact cell-type name as a single label (case‑sensitive, include any hyphens).
# Answer: MF-I
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: Using the provided AnnData object, compute the proportion of each broad cell type (annotation_level0) within each age bin (young vs old). Identify the cell type with the greatest absolute difference in proportion between the two age bins. Answer format: a single label exactly matching the cell type name as it appears in annotation_level0 (shape: label).
# Answer: MF-I
#
# Group goblet cell
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Identify the epithelial cell type whose proportion of cells increases most strongly from the most proximal segment (segment 1) to the most distal segment (segment 30) of the mouse small intestine. For each segment, compute the proportion of each cell type (as defined in the 'cell.type' column) among all cells in that segment, fit a simple linear regression of proportion versus segment number (1‑30), and select the cell type with the largest positive slope. Answer format: a single cell type label exactly as it appears in the 'cell.type' column (case‑sensitive).
# Answer: Goblet cell
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Across the 30 intestinal segments (1 = proximal, 30 = distal) in the provided mouse epithelial scRNA‑seq dataset, compute the proportion of each cell type within each segment and calculate the Spearman rank correlation between segment number and cell‑type proportion. Identify the cell type that shows the strongest positive monotonic trend (i.e., the highest Spearman rho). Answer format: a single cell‑type label exactly as it appears in the 'cell.type' column (shape: label).
# Answer: Goblet cell
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Identify the epithelial cell type whose relative abundance (proportion of cells) shows the strongest monotonic increase from the proximal (segment 1) to the distal (segment 30) end of the mouse small intestine. Answer format: a single label exactly as it appears in the 'cell.type' column (shape: label).
# Answer: Goblet cell
#
# Task 3
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: For each of the 30 intestinal segments (1‑30) compute the proportion of cells belonging to each cell type (as listed in the 'cell.type' column). Then calculate the Spearman correlation between segment number and the proportion of each cell type. Identify the cell type with the highest positive Spearman correlation (strongest monotonic increase along the proximal‑distal axis). Provide the answer as a single label exactly matching the value in the 'cell.type' column (case‑sensitive, including spaces).
# Answer: Goblet cell
#
# Task 4
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Identify the epithelial cell type whose proportion across intestinal segments (1 to 30) shows the strongest positive monotonic gradient (highest Spearman correlation) with segment number. Answer format: a single cell type label exactly as it appears in the 'cell.type' column (shape: label).
# Answer: Goblet cell
#
# Task 5
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Identify the cell type whose proportion across the 30 intestinal segments shows the strongest positive monotonic trend (i.e., the highest Pearson correlation between segment number and the cell-type proportion). Answer format: a single cell type label exactly as it appears in the 'cell.type' column (shape: label).
# Answer: Goblet cell
#
# Group b_cell
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Identify the cell type that exhibits the greatest relative increase in proportion in OLD mice compared to YOUNG mice within this dataset. Report the cell type name as a single lowercase token with any spaces replaced by underscores (shape: label).
# Answer: b_cell
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Using the provided single‑cell RNA‑seq atlas of the aging mouse ovary, compute for each annotated cell type the gene with the largest absolute log2 fold‑change (log2FC) between OLD and YOUNG mice (log2FC = log2(mean_OLD / mean_YOUNG), using CPM‑normalized log1p expression). Identify the cell type whose maximal absolute log2FC is the greatest among all cell types. Answer format: a single lowercase label with underscores (shape: label).
# Answer: b_cell
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Identify the cell type that shows the greatest enrichment in the OLD mice compared to YOUNG mice, measured as the fold‑change of its proportion (OLD/YOUNG). Report the cell type name as a single label with spaces replaced by underscores (shape: label).
# Answer: B_cell
#
# Group r24_p2538
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper1/data.h5ad
# Description: From the provided human brain snRNA‑seq dataset, compute for each donor the percentage of cells annotated as "microglial cell" among that donor's cells. Identify the donor with the highest microglial proportion. Answer format: a single donor identifier (shape: label, exact case as in the data).
# Answer: R24_P2538
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper1/data.h5ad
# Description: From the provided human brain snRNA‑seq dataset, identify the donor (donor_id) that has the highest fraction of cells labeled as "microglial cell". Answer format: a single donor identifier string exactly as it appears in the 'donor_id' column (shape: label).
# Answer: R24_P2538
#
# Group tom_vct
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper5/data.h5ad
# Description: Using the provided single-cell RNA‑seq dataset of human trophoblast organoids, determine which annotated cell type shows the strongest transcriptional response to cytokine exposure. Define the response strength as the total number of genes that are significantly up‑regulated in the cytokine‑treated condition versus the no‑cytokine condition (adjusted p‑value < 0.05 and log2 fold‑change > 0). Report the cell‑type label exactly as it appears in the 'author_cell_type' column. Answer format: a single label (shape: label).
# Answer: TOM_VCT
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper5/data.h5ad
# Description: Identify the author_cell_type (value in the 'author_cell_type' column of adata.obs) that exhibits the largest number of significantly up‑regulated genes (adjusted p‑value < 0.05 and log2 fold‑change > 0) when comparing cytokine‑treated cells versus no‑cytokine cells using Wilcoxon rank‑sum test. Answer format: a single cell‑type label (shape: label).
# Answer: TOM_VCT
#
# Group hepatocyte
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# Description: Using the provided snRNA‑seq dataset, identify the cell type whose relative abundance increases the most after chemotherapy (Stage_Code = PTX) compared to diagnosis (Stage_Code = DX). For each cell type, compute its proportion of cells within each stage, calculate the log2 fold‑change (log2( proportion_PT X / proportion_DX )), and consider only cell types present in both stages. Report the exact cell_type label (as it appears in the 'cell_type' column) with the highest positive log2 fold‑change. Answer format: a single label string.
# Answer: hepatocyte
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# Description: Using the provided snRNA‑seq dataset, compare gene expression between the two treatment stages (Stage_Code = DX for diagnosis and Stage_Code = PTX for post‑chemotherapy). For each cell type, compute the log2 fold‑change (log2FC) of every gene as log2((mean PTX + 1e‑6) / (mean DX + 1e‑6)) using raw counts. Identify, for each cell type, the gene with the highest positive log2FC, then determine which cell type has the largest such positive log2FC among all cell types. Answer format: a single cell‑type label (shape: label).
# Answer: hepatocyte
#
# Group 5
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Using the provided single-nucleus RNA‑seq dataset (dataset2.h5ad), compute for each Seurat cluster (column 'seurat_clusters') the proportion of cells belonging to each treatment condition (column 'Treatment'). Then calculate, for each cluster‑treatment pair, an enrichment score defined as (cluster proportion) / (global proportion of that treatment across all cells). Identify the cluster whose maximum enrichment score (i.e., the most over‑represented treatment in that cluster) is the highest among all clusters. Report the identifier of that cluster exactly as it appears in the 'seurat_clusters' column. Answer format: a single label (shape: label).
# Answer: 5
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# Description: Among the unsupervised Seurat clusters (column 'seurat_clusters') in the provided single-nucleus RNA‑seq dataset, identify the cluster that exhibits the highest proportion of cells annotated with the clinical response "Complete" (consider only cells with a non‑missing Response value). Answer format: a single integer label representing the cluster ID (shape: label).
# Answer: 5
#
# Group 4
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# Description: Using the provided snRNA‑seq dataset of macrophages, perform a differential expression analysis between post‑chemotherapy (Stage_Code = PTX) and pre‑chemotherapy (Stage_Code = DX) cells **within each Seurat cluster** (seurat_clusters). For each cluster, count the number of genes that are significantly up‑regulated in PTX compared to DX, defined as adjusted p‑value < 0.05 and log2 fold‑change > 0.5 (t‑test). Identify the cluster with the **largest** such count. Answer format: a single integer label corresponding to the Seurat cluster identifier (shape: label).
# Answer: 4
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Identify the seurat_clusters label (numeric cluster identifier) that exhibits the highest proportion of MYCN-amplified cells (MYCN_Status == 'AMP') among all clusters. Answer format: a single integer label (shape: label).
# Answer: 4
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Identify the seurat_cluster (label) that exhibits the highest average expression of the MYCN oncogene across all cells in the dataset. Use the 'seurat_clusters' annotation and the expression matrix. Answer format: a single cluster label as a string (e.g., '4'), shape: label.
# Answer: 4
#
# Group control
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Among the experimental conditions in the dataset, which condition exhibits the highest proportion of cells annotated as "cycling macrophage"? Answer format: a single label (shape: label).
# Answer: Control
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Using the provided single-cell dataset, consider only cells annotated as "cycling macrophage" (cell_type == "cycling macrophage"). For each disease condition in the "Condition" column, compute the proportion of cycling macrophage cells among all cells of that condition. Report the condition that has the highest proportion. Answer format: a single condition label (shape: label), exactly as it appears in the "Condition" column.
# Answer: Control
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# Description: Among cells annotated as cytotoxic T cell, which Condition shows the highest average expression of the gene CXCL9? Answer format: a single condition name exactly as it appears in the Condition column (shape: label).
# Answer: Control
#
# Task 3
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Identify the condition (as listed in the 'Condition' column) that has the highest proportion of cells annotated as "cycling macrophage". Answer format: a single label exactly matching one of the Condition values (shape: label).
# Answer: Control
#
# Task 4
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# Description: Identify the disease condition that exhibits the highest proportion of the cell type whose proportion across conditions shows the greatest variance. Answer format: a single label exactly matching the condition name as it appears in the 'Condition' column (shape: label).
# Answer: Control
#
# Task 5
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Identify the condition (as listed in the `Condition` column) that has the highest proportion of cells annotated as "cycling macrophage". Provide the condition name exactly as it appears (case‑sensitive). Answer format: a single label (shape: label).
# Answer: Control
#
# Task 6
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# Description: Within the B cell population, identify which experimental condition shows the highest average expression of the cytokine gene CXCL10. Provide the condition name exactly as it appears in the 'Condition' column (case‑sensitive). Answer format: a single label (shape: label).
# Answer: Control
#
# Task 7
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Determine which disease condition exhibits the highest proportion of cells annotated as "cycling macrophage" among all cells in the dataset. Report the condition name exactly as it appears in the "Condition" column (case-sensitive). Answer format: a single condition label (shape: label).
# Answer: Control
#
# Task 8
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: Using the provided AnnData object, calculate for each Condition the proportion of cells annotated as "cycling macrophage" (i.e., number of cycling macrophage cells divided by the total number of cells in that Condition). Identify the Condition with the highest proportion. Answer format: a single condition label exactly as it appears in the 'Condition' column (shape: label).
# Answer: Control
#
# Group 3427
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/VA_adipocytes.h5ad
# Description: Identify the donor (donor_id) that exhibits the highest average expression of the adipocyte marker gene ADIPOQ across all its cells in the provided dataset. Answer format: a single donor identifier (shape: label).
# Answer: 3427
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/VA_adipocytes.h5ad
# Description: Using the provided UMAP embedding (X_umap) for each cell, compute the variance of the UMAP1 and UMAP2 coordinates separately for each donor (column 'donor_id' in .obs). Then calculate the average of these two variances for each donor. Identify the donor with the highest average variance (i.e., the most dispersed cells in the UMAP space). Answer format: a single donor identifier as a label (shape: label).
# Answer: 3427
#
# Group xist
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_MuSC_data.h5ad
# Description: Within the ICAM1+MuSCs sub-population of the provided mouse muscle stem cell dataset, compare cells from the oldest age group (70-75) versus the youngest age group (15-20). Perform a Wilcoxon rank‑sum differential expression test on the expression matrix stored in the AnnData object, compute log2 fold‑changes, and adjust p‑values using the Benjamini‑Hochberg method. Among genes with adjusted p‑value < 0.05, identify the gene with the greatest absolute log2 fold‑change. Report the gene symbol as a single uppercase HGNC gene symbol (shape: gene_symbol).
# Answer: XIST
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_human_muscle_data.h5ad
# Description: Using the provided single‑cell RNA‑seq dataset, restrict the analysis to cells annotated as MuSC (muscle stem cells). Define two age groups: "young" = Age_group "15-20" and "old" = Age_group "70-75". Perform a differential expression test between old and young MuSC cells using Scanpy's rank_genes_groups with the Wilcoxon method, using the young group as reference and Benjamini‑Hochberg correction for multiple testing. Consider only genes with adjusted p‑value < 0.05. Identify the gene with the greatest absolute log2 fold‑change (old vs young) among these significant genes. Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: XIST
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad
# Description: In the provided placenta infection scRNA‑seq dataset, identify the cell type with the greatest number of cells. Within this cell type, compare cells infected with Listeria monocytogenes (infection label "Lm") to uninfected cells (infection label "UI"). Using the log‑normalized expression matrix, compute the mean expression of each gene in the Lm and UI groups, calculate the log2 fold change (mean_Lm – mean_UI), and report the HGNC gene symbol of the gene with the highest positive log2 fold change. Answer format: a single gene symbol (shape: gene_symbol).
# Answer: XIST
#
# Task 3
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_MuSC_data.h5ad
# Description: Within the dataset, select cells annotated as "MuSC" (annotation_level2 == "MuSC"). From these, keep only the two extreme age groups: 15-20 (young) and 70-75 (old). Normalize each cell to 10,000 counts, apply log1p transformation, and then perform differential expression using Scanpy's rank_genes_groups with groupby='Age_group', groups=['70-75'], reference='15-20', method='t-test_overestim_var'. Identify the gene with the largest positive log2 fold‑change (old vs young). Provide the gene symbol as a single uppercase string (shape: gene_symbol).
# Answer: XIST
#
# Task 4
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_human_muscle_data.h5ad
# Description: Using the provided AnnData file, subset the cells annotated as 'MF-I' (annotation_level0). Within this subset, compare the oldest age group (Age_group = '70-75') to the youngest age group (Age_group = '15-20') and perform differential expression analysis (Wilcoxon test, default Scanpy settings). Report the HGNC gene symbol of the gene with the largest positive log₂ fold‑change that has an adjusted p‑value < 0.05. Answer format: a single gene symbol (shape: gene_symbol, uppercase).
# Answer: XIST
#
# Group b-lymphocytes
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Among the annotated cell types (column 'cluster.names'), which cell type exhibits the greatest fold change in its proportion of cells between old and young mouse ovaries (OLD divided by YOUNG), calculated from raw cell counts? Provide the cell type name exactly as it appears in the 'cluster.names' column. Answer format: a single label (shape: label).
# Answer: B-Lymphocytes
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Using the provided single‑cell atlas of the aging mouse ovary, compute the proportion of each cell type (column 'cluster.names') within the two age groups labeled 'YOUNG' and 'OLD' in the 'age' column. Calculate the fold‑change of each cell type's proportion as (OLD proportion) / (YOUNG proportion). Identify the cell type with the largest fold‑change greater than 1 (i.e., the greatest relative increase from young to old). Answer format: a single cell‑type label (shape: label).
# Answer: B-Lymphocytes
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Using the provided single‑cell atlas of the aging mouse ovary, compute for each cell cluster (column 'cluster.names') the proportion of cells from the OLD and YOUNG age groups (column 'age'), then calculate the enrichment ratio (OLD proportion divided by YOUNG proportion). Report the cluster name with the highest enrichment ratio. Answer format: a single cluster label (shape: label, case‑sensitive, exactly as it appears in 'cluster.names').
# Answer: B-Lymphocytes
#
# Group alzheimer disease
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper1/data.h5ad
# Description: From the provided single-nucleus RNA‑seq dataset, compute the proportion of microglial cells within each disease category (Alzheimer disease, Pick disease, progressive supranuclear palsy, normal). Identify the disease that exhibits the highest microglial cell proportion. Answer format: a single disease name as a label (exact string as appears in the 'disease' column).
# Answer: Alzheimer disease
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper1/data.h5ad
# Description: Using the provided single-nucleus RNA‑seq dataset, calculate for each disease category (as listed in the 'disease' column) the proportion of cells annotated as "microglial cell" (based on the 'cell_type' column). Identify the disease with the highest microglial cell proportion. Answer format: a single disease name exactly as it appears in the 'disease' column (shape: label).
# Answer: Alzheimer disease
#
# Group interferon-response
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper3/data.h5ad
# Description: Using the provided scRNA‑seq dataset, compute the proportion of cells belonging to each transcriptionally defined cluster (column 'cluster_name') within each experimental condition ('Control' and 'Deprived'). Calculate the log2 fold‑change of the Deprived proportion over the Control proportion for every cluster (add a tiny epsilon = 1e‑6 to avoid division by zero). Report the exact cluster name that exhibits the highest positive log2 fold‑change (i.e., the greatest enrichment in the Deprived condition). Answer format: a single label (case‑preserved cluster name).
# Answer: Interferon-response
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper3/data.h5ad
# Description: Determine which cell cluster (as labeled in the 'cluster_name' column) exhibits the greatest absolute change in its proportion of cells between the 'Control' and 'Deprived' experimental conditions. Report the cluster name exactly as it appears (case‑sensitive, including hyphens and spaces). Answer format: a single label (shape: label).
# Answer: Interferon-response
#
# Group csh1
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper5/data.h5ad
# Description: Within the single-cell RNA‑seq dataset of human trophoblast organoids, consider only cells annotated as "extravillous trophoblast". Perform a differential expression analysis comparing the "cytokines" treatment group against the "no_cytokines" control group (using standard library‑size normalization, log‑transformation, and the Wilcoxon rank‑sum test on all genes). Identify the gene that shows the largest positive log2‑fold‑change (i.e., strongest up‑regulation) in the cytokine‑treated cells relative to control. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: CSH1
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper5/data.h5ad
# Description: Within the extravillous trophoblast cell type, identify the gene that shows the highest positive log2 fold-change when comparing cells treated with cytokines versus no cytokines. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: CSH1
#
# Group anbl12p1-like chemotherapy
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Within the snRNA‑seq dataset, cells are assigned to six Seurat clusters (0‑5). Considering only the cells in cluster 0, compute the average expression of the gene MYCN for each distinct value in the 'Treatment' metadata column. Identify the treatment that yields the highest mean MYCN expression. Answer format: a single label matching exactly the treatment string as it appears in adata.obs['Treatment'] (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Using the provided snRNA‑seq dataset of neoplastic cells, compute the average expression of the oncogene MYCN (gene symbol) in diagnostic (Stage_Code == "DX") cells and in each post‑treatment (Stage_Code == "PTX") regimen. For each post‑treatment regimen, calculate the log2‑fold‑change of the mean MYCN expression relative to the diagnostic mean (add a small epsilon = 1e‑6 to avoid division by zero). Identify the post‑treatment regimen with the largest positive log2‑fold‑change. Report the exact treatment name as it appears in the 'Treatment' column. Answer format: a single label (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Among the malignant neuroblast cells (cell_type == 'neuroblast (sensu Vertebrata)' and malignancy == 'Malignant'), compute the average expression of the oncogene MYCN for each Treatment group. Identify the Treatment label with the highest average MYCN expression. Answer format: a single treatment label string exactly as it appears in the data (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 3
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Identify the treatment condition (as listed in the 'Treatment' column of the provided AnnData object) that exhibits the highest average normalized expression of the gene MYCN across all cells. Provide the answer as a single exact label string (shape: label), matching the Treatment entry case‑sensitively and without extra spaces.
# Answer: ANBL12P1-like chemotherapy
#
# Task 4
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Within the neuroblastoma cells (cell_type == 'neuroblast (sensu Vertebrata)') in the provided dataset, compute the average raw count expression of the oncogene MYCN for each distinct Treatment group. Return the Treatment name that yields the highest average MYCN expression. Answer format: a single label exactly matching the Treatment string (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Group mt-co3
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# Description: Within the most abundant seurat cluster of macrophage nuclei, perform differential expression between the post‑treatment (PTX) and diagnosis (DX) groups. Identify the gene that is most significantly up‑regulated in PTX versus DX (i.e., the up‑regulated gene with the smallest Benjamini‑Hochberg adjusted p‑value). Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: MT-CO3
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: In the provided single‑cell atlas of the aging mouse ovary, restrict the analysis to cells annotated as "stromal cell". Using the log‑normalized expression matrix, perform a differential expression comparison between cells from the OLD age group versus the YOUNG age group (Wilcoxon rank‑sum test, all genes). Identify the gene that exhibits the greatest absolute log2 fold‑change (|log2FC|) between the two age groups. Report the official mouse gene symbol of this gene. Answer format: a single gene symbol (shape: gene_symbol, uppercase).
# Answer: MT-CO3
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# Description: Within the malignant cells of the dataset, identify the most abundant Seurat cluster (by cell count). In that dominant cluster, compare cells from the pre‑treatment stage (Stage_Code = "DX") to post‑treatment stage (Stage_Code = "PTX"). Using a Wilcoxon rank‑sum test (as implemented by Scanpy's rank_genes_groups) and considering genes with adjusted p‑value < 0.05, report the gene that shows the greatest positive log2 fold‑change (i.e., strongest up‑regulation) after chemotherapy. Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: MT-CO3
#
# Group 464c
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_MuSC_data.h5ad
# Description: Among the donors in the dataset, which donor contributes the highest proportion of cells labeled as 'MYOG+MuSCs' (relative to its total cells)? Answer format: a single donor identifier string (shape: label).
# Answer: 464C
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_MuSC_data.h5ad
# Description: Identify the donor (DonorID) that exhibits the highest fraction of cells annotated as 'MYOG+MuSCs' among all cells from that donor. Report the DonorID exactly as it appears (e.g., '464C'). Answer format: a single label (shape: label).
# Answer: 464C
#
# Group nuclei
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_human_muscle_data.h5ad
# Description: Using the provided AnnData object, identify the cell type with the highest number of cells in the 'annotation_level1' column. Subset the data to this cell type, normalize, log‑transform, select 2,000 highly variable genes, scale, and compute 30 principal components. Build a k‑nearest‑neighbour graph with k = 30 on the PCA space and compute the inverse Simpson index (iLISI) of the 'batch' labels among each cell's neighbours. Report the batch (value from the 'batch' column) that has the lowest mean iLISI across all cells of this cell type. Answer format: a single label (shape: label).
# Answer: nuclei
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: Using the scANVI embedding (X_scANVI) provided in the AnnData object, compute the 30‑nearest‑neighbor graph (Euclidean distance) for all cells. For each cell, calculate the fraction of its 30 neighbors that belong to the same batch (the 'batch' column in .obs). Then average this fraction across all cells within each batch. Report the batch that has the highest average same‑batch neighbor fraction (i.e., the batch showing the poorest mixing). Answer format: a single lowercase label (shape: label).
# Answer: nuclei
#
# Group mf-isn(fg)
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Identify the annotation_level1 cell type that exhibits the highest average expression of the gene MYH7 across all nuclei in the dataset. Answer format: a single cell type label exactly as it appears in the 'annotation_level1' column (shape: label).
# Answer: MF-Isn(fg)
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Using the provided muscle nuclei dataset, compute for each fine-grained cell type (annotation_level1) the proportion of cells contributed by each donor (DonorID). Then calculate the coefficient of variation (CV = standard deviation / mean) of these donor-wise proportions across all donors. Report the cell type (annotation_level1 label) that exhibits the highest CV. Answer format: a single label (shape: label).
# Answer: MF-Isn(fg)
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: After removing cells with scrublet_score > 0.2, compute the average percent_mito for each cell type in the annotation_level0 column. Report the cell type (exact string as it appears in annotation_level0) that has the highest average percent_mito. Answer format: a single label (shape: label).
# Answer: MF-Isn(fg)
#
# Task 3
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: After removing cells with a Scrublet doublet score greater than 0.1, compute the mean percent_mito for each cell type defined in the column 'annotation_level1'. Which cell type has the highest average percent_mito? Answer format: a single label exactly as it appears in 'annotation_level1' (shape: label).
# Answer: MF-Isn(fg)
#
# Task 4
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: Using the provided AnnData file (/mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad), compute the average raw counts expression of the gene MYH1 for each cell type defined in the 'annotation_level2' column of adata.obs. Identify the cell type with the highest mean MYH1 expression. Answer format: a single label that matches exactly one of the annotation_level2 categories (shape: label).
# Answer: MF-IIsn(fg)
#
# Group 9
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Among the 30 intestinal segments (labeled 1 to 30) in the provided mouse epithelial single‑cell dataset, identify the segment that has the highest proportion of cells annotated as "stem cell" (i.e., #stem cells / total cells in the segment). Answer format: a single segment label (numeric string) with no spaces (shape: label).
# Answer: 9
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Using the provided single-cell dataset of mouse intestinal epithelial cells, calculate for each intestinal segment (1 to 30) the proportion of cells annotated as "Stem cell" (i.e., number of Stem cell entries divided by total cells in that segment). Identify the segment that has the highest Stem cell proportion. Answer format: a single integer representing the segment number (shape: number).
# Answer: 9
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Identify the intestinal segment (1-30) that has the highest proportion of Stem cells among all cells in the dataset. Answer format: a single integer representing the segment number (shape: number).
# Answer: 9
#
# Task 3
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Using the provided single-cell RNA‑seq dataset of mouse intestinal epithelial cells, compute for each of the 30 intestinal segments the proportion of cells annotated as "Stem cell" (i.e., number of Stem cells divided by total cells in that segment). Identify the segment that has the highest Stem‑cell proportion. Answer format: a single segment identifier as a label (shape: label).
# Answer: 9
#
# Task 4
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/VA_adipocytes.h5ad
# Description: From the provided single-nucleus RNA‑seq dataset of human visceral adipose tissue, identify the Seurat cluster (column 'seurat_clusters' in .obs) that exhibits the highest median mitochondrial gene expression percentage (column 'percent.mt'). Report the cluster identifier exactly as it appears (shape: label).
# Answer: 9
#
# Task 5
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# Description: Determine which intestinal segment (1‑30) has the highest proportion of Stem cells among all cells in the dataset. Report the segment number as an integer (shape: number).
# Answer: 9
#
# Group b cell
# ----------------------------------------------------------------------------------------------------
# Task 0
# ...
# Description: Using the provided myonuclei single‑cell dataset, determine which non‑missing myofiber_type category has the highest average expression of the gene MYH7. Report the myofiber_type label exactly as it appears in the data (case‑sensitive, including any '+' characters). Answer format: a single label (shape: label).
# Answer: MYH2+MYH7+
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Among the myofiber_type categories present in the dataset (excluding the 'nan' category), which myofiber type shows the highest average raw expression level of the muscle gene MYH7? Answer format: a single myofiber_type label exactly as it appears in the 'myofiber_type' column (shape: label, case‑sensitive).
# Answer: MYH2+MYH7+
#
# Group 2
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: Using the snRNA‑seq AnnData file at /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad, classify each cell into a 'baseline' or 'post' treatment group based on its 'Treatment' annotation (case‑insensitive): label as 'baseline' if the string contains any of the substrings "primary", "pre", "baseline", or "dx"; label as 'post' if the string contains any of "post", "after", or "resection". Exclude cells that are not assigned to either group. For each value of the column 'seurat_clusters', compute the fraction of cells that are baseline and the fraction that are post. Identify the cluster with the greatest absolute difference between its baseline fraction and post fraction. Return the identifier of that cluster as a single label (shape: label).
# Answer: 2
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: After Harmony batch correction, compute for each Seurat cluster (adata.obs['seurat_clusters']) the fraction of cells belonging to the most abundant original batch (adata.obs['orig.ident']). Identify the cluster with the highest such fraction (i.e., the poorest batch mixing). Answer format: a single cluster label as a string (shape: label).
# Answer: 2
#
# Group anbl0532-like therapy with cisplatin & etoposide
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# Description: Among the macrophage cells, which Treatment has the highest proportion of cells with Response == "Complete"? If multiple treatments share the maximal proportion, return the alphabetically first one. Answer format: a single treatment name (shape: label).
# Answer: ANBL0532-like therapy with cisplatin & etoposide
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# Description: From the 'Treatment' column, identify the treatment that exhibits the highest fraction of cells labeled as 'Complete' in the 'Response' column, considering only treatments that have at least 5 cells. If multiple treatments share the highest fraction, select the one that comes first alphabetically. Answer format: a single label (exact treatment string) (shape: label).
# Answer: ANBL0532-like therapy with cisplatin & etoposide
#
# Group 3313
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# Description: Identify the donor (donor_id) that contributes the highest proportion of cells annotated as "mesothelial cell" relative to its total number of cells in the dataset. Answer format: a single donor ID string (shape: label).
# Answer: 3313
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# Description: Using the provided snRNA‑seq AnnData object, identify the cell type that has the highest overall abundance across all cells. Then, among all donors (column 'donor_id'), determine which donor exhibits the highest proportion of that cell type (proportion = cells of that type / total cells for the donor). Answer format: a single donor identifier string (shape: label).
# Answer: 3313
#
# Group neuron
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper7/data/dataset2.h5ad
# Description: Using the provided scRNA‑seq dataset, identify the cell type that exhibits the highest average expression of the top marker gene (MAB21L2) reported in the pre‑computed differential expression results. Answer format: a single lowercase cell type label (shape: label).
# Answer: neuron
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper6/data/dataset1.h5ad
# Description: After removing cells with a Scrublet doublet score > 0.5, compute the median RNA UMI count (nCount_RNA) for each distinct cell class (the values in adata.obs['Class']). Which class has the highest median? Answer format: a single label (exact string as it appears in the Class column).
# Answer: Neuron
#
# Group mis-c
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# Description: Determine which Condition has the highest proportion of cells annotated as "natural killer cell" in the dataset. Answer format: a single condition label (shape: label).
# Answer: MIS-C
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# Description: From the provided single-cell dataset, consider only cells annotated as 'macrophage' or 'cycling macrophage'. For each Condition, compute the proportion of cells that are labeled 'cycling macrophage' among these selected cells. Identify the Condition with the highest such proportion. Answer format: a single Condition label (shape: label).
# Answer: MIS-C
#
# Task 2
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# Description: Using the provided single-cell RNA‑seq dataset of human cardiac lymphocytes, consider the cell type annotations in the column 'author_cell_type'. Define NK cells as those labeled 'NK_CD16hi' or 'NK_CD56hi', and define CD8+ T cells as any cell whose annotation starts with 'CD8T_'. For each disease condition (values in the 'Condition' column), compute the average expression of the gene IFNG (interferon‑γ) separately in NK cells and in CD8+ T cells. Then calculate the difference (average IFNG in NK cells minus average IFNG in CD8+ T cells) for each condition. Identify the condition with the largest positive difference (i.e., the strongest relative up‑regulation of IFNG in NK cells compared to CD8+ T cells). Answer format: a single label exactly matching the condition name as it appears in the 'Condition' column (shape: label).
# Answer: MIS-C
#
# Group adh+fibro
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper7/data/dataset2.h5ad
# Description: Using the provided scRNA‑seq dataset, compare the earliest developmental stage (adj_stage = Pcw5.1) to the latest stage (adj_stage = Pcw9.3). For each stage, compute the proportion of cells belonging to each cell type (as given in the 'celltype' column). Identify the cell type whose proportion increase (latest stage proportion minus earliest stage proportion) is the greatest. Answer format: a single cell type label exactly as it appears in the 'celltype' column (shape: label).
# Answer: ADH+Fibro
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper7/data/dataset2.h5ad
# Description: Identify the cell type that shows the greatest increase in relative abundance (proportion of cells) from the earliest developmental stage (Pcw5.1) to the latest developmental stage (Pcw9.3) in the dataset. Answer format: a single cell type label exactly as it appears in the 'celltype' column (shape: label).
# Answer: ADH+Fibro
#
# Group pf
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad
# Description: In the dataset, consider only Hofbauer cells sampled at 24 hours post‑infection. For each infection condition (Lm, Tg, Pf) perform a differential expression analysis versus the uninfected (UI) cells using Scanpy's Wilcoxon rank‑sum test (all genes, no preprocessing). Count the number of genes that satisfy adjusted p‑value < 0.05 and log2‑fold‑change > 0.25. Which infection condition has the largest such count? Answer format: a single infection label (one of UI, Lm, Tg, Pf).
# Answer: Pf
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad
# Description: In the dataset, consider only the cells annotated as "Hofbauer cell". For each infection condition (UI, Lm, Pf, Tg), compute the average raw (unnormalized) count of the gene IL6 across those Hofbauer cells. Identify the infection condition with the highest mean IL6 expression. Answer format: a single two‑letter label exactly as it appears in the "infection" column (shape: label).
# Answer: Pf
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad
# Description: Within the cell type 'Hofbauer cell', determine which infection condition ('UI', 'Tg', 'Pf', or 'Lm') exhibits the highest average expression of the gene CXCL10. Report the answer as the exact infection label (case-sensitive) with shape: label.
# Answer: Pf
#
# Group myh1+myh2+myh7+
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Identify the myofiber_type annotation that exhibits the highest average percent_mito across all nuclei in the dataset. Answer format: a single label exactly as it appears in the 'myofiber_type' column (shape: label).
# Answer: MYH1+MYH2+MYH7+
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# Description: Identify the myofiber_type that exhibits the strongest donor-specific bias, defined as the highest proportion of its nuclei contributed by a single donor. Answer format: a single label exactly as it appears in the 'myofiber_type' column (shape: label).
# Answer: MYH1+MYH2+MYH7+
#
# Group 11
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# Description: Using the provided AnnData object, filter out cells flagged as doublets (`predicted_doublet == True`) and cells with mitochondrial transcript proportion > 10%. Then, compute the inverse Local Inverse Simpson’s Index (iLISI) for donor mixing within each Leiden cluster (using the `X_pca` embedding, k=30 nearest neighbors). Report the Leiden cluster identifier that has the lowest iLISI (i.e., the cluster with the poorest donor mixing). Answer format: a single integer (shape: label).
# Answer: 11
#
# Task 1
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# Description: Using the provided snRNA‑seq dataset, compare the relative abundance of Seurat clusters between the two treatment stages indicated by the 'Stage_Code' column (DX = pre‑chemotherapy, PTX = post‑chemotherapy). For each cluster, compute the proportion of cells within each stage, then calculate the log2 fold‑change (PTX proportion / DX proportion). Identify the cluster that shows the greatest positive log2 fold‑change (i.e., the strongest increase after chemotherapy). Answer format: a single cluster identifier as a label (shape: label).
# Answer: 11
#
# Group fibroblast
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# Description: In the provided snRNA‑seq dataset, use the binary metadata column **MYCN_Status** (values: 'AMP' and 'NON') as the grouping variable. Identify the gene that has the highest value in the column `vf_vst_counts_variance.standardized` among all genes with a non‑missing `gene_name`. For each distinct `cell_type`, compute the average expression of this gene in the 'AMP' and 'NON' groups, then calculate the log2 fold‑change (NON over AMP) adding a small epsilon (1e‑6) to avoid division by zero. Return the **cell_type** that shows the largest positive log2 fold‑change. Answer format: a single lowercase label with underscores (shape: label).
# Answer: fibroblast
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad
# Description: Identify the cell type that exhibits the greatest enrichment (highest fold change of proportion) in Plasmodium falciparum (Pf) infected samples compared to uninfected (UI) samples at the 24 hour time point. Answer format: a single lowercase label without spaces (shape: label).
# Answer: fibroblast
#
# Group small intestine peyer's patch
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper1/cxg_data.h5ad
# Description: Using the provided scRNA‑seq dataset, compute for each tissue the proportion of cells annotated as 'regulatory T cell' (number of regulatory T cells divided by total cells in that tissue). Identify the tissue with the highest proportion. Answer format: a single tissue label exactly as it appears in the 'tissue' column (shape: label).
# Answer: small intestine Peyer's patch
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper1/cxg_data.h5ad
# Description: Using the provided scRNA‑seq dataset, identify regulatory T cells (Tregs) by selecting cells whose 'final_annotation' contains the substring "Treg" (case‑insensitive) or whose 'cell_type' equals "regulatory T cell". For each tissue (values in the 'tissue' column), compute the proportion of Treg cells among all cells in that tissue. Report the tissue with the highest Treg proportion. Answer format: a single tissue label exactly as it appears in the 'tissue' column (shape: label).
# Answer: small intestine Peyer's patch
#
# Task 2
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper1/cxg_data.h5ad
# Description: Among the four sampled tissues, which tissue exhibits the highest proportion of regulatory T cell cells? Report the tissue name exactly as it appears in the 'tissue' column (case‑sensitive, including spaces and punctuation). Answer format: a single label (shape: label).
# Answer: small intestine Peyer's patch
#
# Group mf_type-myh8+
# ----------------------------------------------------------------------------------------------------
# Task 0
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: Identify the annotation_level2 cell type whose proportion of cells originating from the 'cells' batch (i.e., fraction = #cells in batch 'cells' / total #cells for that type) is maximal. If multiple cell types share the maximal proportion, return the one that comes first alphabetically. Answer format: a single label (shape: label) exactly as it appears in the annotation_level2 column.
# Answer: MF_type-MYH8+
#
# Task 1
# Dataset path: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# Description: Using the provided single-nucleus/cell dataset, consider the fine-grained cell-type annotation column 'annotation_level2'. Restrict the analysis to cell types that contain at least 100 cells. Compute the average mitochondrial RNA proportion ('percent_mito') for each remaining cell type and identify the one with the highest mean value. Answer format: a single cell-type label exactly as it appears in 'annotation_level2' (shape: label).
# Answer: MF_type-MYH8+

# %%
# Dict with the following 
# - keys: nonsingle GTA keys
# - values: list of duplicate tasks ids where the FIRST task id 
#           refers to the representative of the whole group
duplicates_by_gta = {
    "paep": [[0, 1]],
    "lymphocyte": [[2, 0], [3, 4], [1]],
    "monocyte": [[0], [1]],
    "3357": [[0, 1, 2]],
    "nmj accessory": [[0, 2], [4, 1], [3]],
    "mf-i": [[0], [1], [2]],
    "goblet cell": [[3, 1, 2, 4], [0], [5]],
    "b_cell": [[2, 0], [1]],
    "r24_p2538": [[1, 0]],
    "tom_vct": [[1, 0]],
    "hepatocyte": [[0], [1]],
    "5": [[0], [1]],
    "4": [[0], [1], [2]],
    "control": [[8, 0, 1, 3, 5, 7], [2], [4], [6]],
    "3427": [[0], [1]],
    "xist": [[0], [1], [2], [3], [4]],
    "b-lymphocytes": [[1, 0, 2]],
    "alzheimer disease": [[1, 0]],
    "interferon-response": [[0], [1]],
    "csh1": [[0, 1]],
    "anbl12p1-like chemotherapy": [[0], [1], [2], [3], [4]],
    "mt-co3": [[0], [1], [2]],
    "464c": [[1, 0]],
    "nuclei": [[0], [1]],
    "mf-isn(fg)": [[0], [1], [2], [3], [4]],
    "9": [[1, 0, 2, 3, 5], [4]],
    "b cell": [[3, 0], [1], [2]],
    "13": [[0], [1]],
    "endothelial_cell": [[3, 0, 2], [1]],
    "adipocyte of omentum tissue": [[0], [1], [2], [3]],
    "grin2a": [[0], [1]],
    "caecum": [[0], [1]],
    "6720483e21rik": [[2, 1], [0]],
    "evt_late_3": [[1, 0, 2, 4], [3]],
    "cardiac_neuron": [[0], [1]],
    "mesenteric lymph node": [[1, 0, 2]],
    "tnfrsf12a+muscs": [[2, 1], [0]],
    "500c": [[0], [1]],
    "8": [[2, 0, 1, 3, 4]],
    "14": [[1, 2], [0]],
    "3": [[0, 1], [2]],
    "20": [[1, 0]],
    "central memory cd4-positive, alpha-beta t cell": [[0, 1]],
    "fp236383.1": [[0], [1]],
    "young": [[0], [1]],
    "mf-iisc(fg)": [[0], [1]],
    "tg": [[3, 1], [0], [2], [4]],
    "syncytiotrophoblast cell": [[0], [1]],
    "anbl 09p1": [[0], [1]],
    "mf_typei(cytoplasmic)": [[0], [1]],
    "myh2+myh7+": [[0], [1]],
    "2": [[0], [1]],
    "anbl0532-like therapy with cisplatin & etoposide": [[0], [1]],
    "3313": [[0], [1]],
    "neuron": [[0], [1]],
    "mis-c": [[0], [1], [2]],
    "adh+fibro": [[0, 1]],
    "pf": [[0], [1], [2]],
    "myh1+myh2+myh7+": [[0], [1]],
    "11": [[0], [1]],
    "fibroblast": [[0], [1]],
    "small intestine peyer's patch": [[0, 2], [1]],
    "mf_type-myh8+": [[0], [1]],
}

# %%
assert sorted(nonsingle_keys) == sorted(duplicates_by_gta.keys())

# %%
for gta_key in nonsingle_keys:
    tasks = tasks_by_gta[gta_key]
    dups_ids = duplicates_by_gta[gta_key]
    assert list(range(len(tasks))) == sorted(sum(dups_ids, []))

# %%
print(f"Duplicate groups: {sum(len(dups_ids) for dups_ids in duplicates_by_gta.values())}")
# Out:
# Duplicate groups: 137

# %%
def get_clean_tasks(tasks_by_key, duplicates_by_key):
    clean_tasks = []

    for key, tasks in tasks_by_key.items():
        task_ids = set(range(len(tasks)))
        
        for dup_ids in duplicates_by_key.get(key, []):
            rem_tids = set(dup_ids[1:])  # the first index is the representative of a duplicates group
            task_ids -= rem_tids

        clean_tasks.extend([tasks[tid] for tid in task_ids])

    return clean_tasks

# %%
clean_tasks = get_clean_tasks(tasks_by_gta, duplicates_by_gta)
print(f"Tasks after GTA-wise filtration: {len(clean_tasks)}")
# Out:
# Tasks after GTA-wise filtration: 286

# %%
datasets_list = load_data("/mlbio_scratch/kodryan/Biomni/data/all_sc_datasets.json")

# %%
tasks_by_dataset = {ds: [task for task in clean_tasks if task['dataset_path'] == ds] for ds in datasets_list}

# %%
for did, (dataset_path, tasks) in enumerate(tasks_by_dataset.items(), 1):
    print(f"Dataset {did}: {dataset_path}")
    print(f"# tasks: {len(tasks)}")
    print()
# Out:
# Dataset 1: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# # tasks: 15
#
# Dataset 2: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# # tasks: 16
#
# Dataset 3: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# # tasks: 14
#
# Dataset 4: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# # tasks: 13
#
# Dataset 5: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# # tasks: 15
#
# Dataset 6: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# # tasks: 11
#
# Dataset 7: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# # tasks: 12
#
# Dataset 8: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/VA_adipocytes.h5ad
# # tasks: 16
#
# Dataset 9: /mlbio_scratch/videnovi/papers_BIBA/paper6/data/dataset1.h5ad
# # tasks: 16
#
# Dataset 10: /mlbio_scratch/videnovi/papers_BIBA/paper7/data/dataset2.h5ad
# # tasks: 15
#
# Dataset 11: /mlbio_scratch/panigrah/agents/data/nature/paper1/cxg_data.h5ad
# # tasks: 13
#
# Dataset 12: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_MuSC_data.h5ad
# # tasks: 14
#
# Dataset 13: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_human_muscle_data.h5ad
# # tasks: 16
#
# Dataset 14: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad
# # tasks: 14
#
# Dataset 15: /mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonucleicells_data.h5ad
# # tasks: 16
#
# Dataset 16: /mlbio_scratch/panigrah/agents/data/nature/paper5/mouse_data.h5ad
# # tasks: 8
#
# Dataset 17: /mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad
# # tasks: 12
#
# Dataset 18: /mlbio_scratch/panigrah/agents/data/cell/paper1/data.h5ad
# # tasks: 14
#
# Dataset 19: /mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad
# # tasks: 15
#
# Dataset 20: /mlbio_scratch/panigrah/agents/data/cell/paper3/data.h5ad
# # tasks: 10
#
# Dataset 21: /mlbio_scratch/panigrah/agents/data/cell/paper5/data.h5ad
# # tasks: 11

# %%
for dataset_path, tasks in tasks_by_dataset.items():
    print(f"Dataset: {dataset_path}")
    print(100 * '-')
    for tid, task in enumerate(tasks):
        print(f"Task {tid}")
        print(f"Description: {task['task_description']}")
        print(f"Answer: {task['ground_truth_answer']}")
        print()
# Out:
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset1.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Using the provided single-nucleus RNA‑seq dataset (dataset1.h5ad), compute the mean Euclidean distance between pre‑treatment cells (where the 'Response' column is missing/NaN) and post‑treatment cells (where 'Response' is not NaN) for each unique value in the 'malignancy' column, based on the first 30 principal components stored in adata.obsm['X_pca']. Report the malignancy label that has the largest mean pre‑post distance. Answer format: a single token exactly matching one entry of the 'malignancy' column (shape: label).
# Answer: Nonmalignant
#
# Task 1
# Description: Using the provided snRNA‑seq dataset, identify the cell type whose relative abundance increases the most after chemotherapy (Stage_Code = PTX) compared to diagnosis (Stage_Code = DX). For each cell type, compute its proportion of cells within each stage, calculate the log2 fold‑change (log2( proportion_PT X / proportion_DX )), and consider only cell types present in both stages. Report the exact cell_type label (as it appears in the 'cell_type' column) with the highest positive log2 fold‑change. Answer format: a single label string.
# Answer: hepatocyte
#
# Task 2
# Description: Using the provided snRNA‑seq dataset, compare gene expression between the two treatment stages (Stage_Code = DX for diagnosis and Stage_Code = PTX for post‑chemotherapy). For each cell type, compute the log2 fold‑change (log2FC) of every gene as log2((mean PTX + 1e‑6) / (mean DX + 1e‑6)) using raw counts. Identify, for each cell type, the gene with the highest positive log2FC, then determine which cell type has the largest such positive log2FC among all cell types. Answer format: a single cell‑type label (shape: label).
# Answer: hepatocyte
#
# Task 3
# Description: Among the unsupervised Seurat clusters (column 'seurat_clusters') in the provided single-nucleus RNA‑seq dataset, identify the cluster that exhibits the highest proportion of cells annotated with the clinical response "Complete" (consider only cells with a non‑missing Response value). Answer format: a single integer label representing the cluster ID (shape: label).
# Answer: 5
#
# Task 4
# Description: Using the provided snRNA‑seq dataset, consider only cells annotated as malignant neuroblastoma (malignancy == "Malignant" and cell_type == "neuroblast (sensu Vertebrata)"). Compare the pre‑treatment group (Stage_Code == "DX") with the post‑treatment group (Stage_Code == "PTX"). Compute the mean expression of each gene in each group, calculate log2 fold‑change (add a pseudocount of 1e-6 to avoid division by zero), and identify the gene with the largest positive log2 fold‑change (i.e., the most up‑regulated after treatment). Provide the answer as a single HGNC gene symbol (shape: gene_symbol).
# Answer: CYP11B2
#
# Task 5
# Description: Within the malignant cells of the dataset, identify the most abundant Seurat cluster (by cell count). In that dominant cluster, compare cells from the pre‑treatment stage (Stage_Code = "DX") to post‑treatment stage (Stage_Code = "PTX"). Using a Wilcoxon rank‑sum test (as implemented by Scanpy's rank_genes_groups) and considering genes with adjusted p‑value < 0.05, report the gene that shows the greatest positive log2 fold‑change (i.e., strongest up‑regulation) after chemotherapy. Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: MT-CO3
#
# Task 6
# Description: Identify the cell type (as listed in the 'cell_type' column) that has the highest proportion of cells labeled as 'Complete' in the 'Response' column. Answer format: a single label exactly matching the cell_type entry (shape: label).
# Answer: cortical cell of adrenal gland
#
# Task 7
# Description: Using the provided snRNA‑seq dataset, compute for each integrated cluster (column 'integrated_snn_res.0.2') the proportion of cells labeled as 'Malignant' within the diagnosis stage (Stage_Code = DX) and the post‑chemotherapy stage (Stage_Code = PTX). Identify the cluster that shows the largest positive difference (post‑chemotherapy proportion minus diagnosis proportion). Answer format: a single cluster identifier as a string (shape: label).
# Answer: 14
#
# Task 8
# Description: Using the provided snRNA‑seq dataset, compute for each Seurat cluster (seurat_clusters) the fraction of cells annotated as 'Malignant' within the diagnosis (DX) and post‑chemotherapy (PTX) stages. Identify the cluster that shows the greatest positive increase in malignant fraction from DX to PTX (i.e., PTX fraction minus DX fraction is maximal). Answer format: a single cluster identifier as a label (e.g., "14").
# Answer: 14
#
# Task 9
# Description: In the provided snRNA‑seq dataset of high‑risk neuroblastoma, consider only cells annotated as 'Malignant'. Compare the two treatment stages: pre‑treatment (Stage_Code = DX) and post‑treatment (Stage_Code = PTX). For each gene, compute the average expression across cells in each stage, add a pseudocount of 1, and calculate the log2 fold‑change (log2FC = log2[(mean_PTX+1)/(mean_DX+1)]). Identify the gene with the largest positive log2FC (i.e., the strongest up‑regulation after chemotherapy). Answer format: a single HGNC gene symbol (uppercase).
# Answer: RALYL
#
# Task 10
# Description: Among the annotated cell types in the dataset, which cell type shows the largest positive change in the fraction of cells labeled as 'Malignant' when comparing the diagnostic stage (DX) to the post‑chemotherapy stage (PTX)? Report the cell type name exactly as it appears in the 'cell_type' column (shape: label).
# Answer: kidney cell
#
# Task 11
# Description: Using the provided snRNA‑seq dataset of high‑risk neuroblastoma, consider only cells annotated as malignant (malignancy == 'Malignant') and of cell type 'neuroblast (sensu Vertebrata)'. Infer treatment condition from the sample identifier: identifiers ending with '_REG1' correspond to the pre‑treatment group and those ending with '_REG2' to the post‑treatment group. Compute the average expression of each gene across cells in each group, calculate the log2 fold‑change (post / pre) with a pseudocount of 1e‑6, and identify the gene with the greatest absolute log2 fold‑change. Provide the HGNC gene symbol of that gene as the answer. Answer format: a single gene symbol (shape: gene_symbol).
# Answer: SYNJ2BP-COX16
#
# Task 12
# Description: Identify the cell type that exhibits the highest proportion of malignant cells in the dataset. Provide the exact cell type label as it appears in the 'cell_type' column of the AnnData object (shape: label).
# Answer: neuroblast (sensu Vertebrata)
#
# Task 13
# Description: Using the provided snRNA‑seq dataset, compare the relative abundance of Seurat clusters between the two treatment stages indicated by the 'Stage_Code' column (DX = pre‑chemotherapy, PTX = post‑chemotherapy). For each cluster, compute the proportion of cells within each stage, then calculate the log2 fold‑change (PTX proportion / DX proportion). Identify the cluster that shows the greatest positive log2 fold‑change (i.e., the strongest increase after chemotherapy). Answer format: a single cluster identifier as a label (shape: label).
# Answer: 11
#
# Task 14
# Description: Identify the cluster (as given in the 'seurat_clusters' column) that shows the largest absolute difference in mean log1p‑normalized expression of the gene MKI67 between diagnostic (DX) and post‑treatment (PTX) samples (Stage_Code). Report the cluster identifier as a string label (shape: label).
# Answer: 15
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Using the provided snRNA‑seq dataset, identify the batch (orig.ident) that exhibits the highest average expression of the oncogene MYCN. Report the answer as the exact batch identifier string (shape: label).
# Answer: NB_7767_3495_REG1
#
# Task 1
# Description: Using the provided single-nucleus RNA‑seq dataset (dataset2.h5ad), compute for each Seurat cluster (column 'seurat_clusters') the proportion of cells belonging to each treatment condition (column 'Treatment'). Then calculate, for each cluster‑treatment pair, an enrichment score defined as (cluster proportion) / (global proportion of that treatment across all cells). Identify the cluster whose maximum enrichment score (i.e., the most over‑represented treatment in that cluster) is the highest among all clusters. Report the identifier of that cluster exactly as it appears in the 'seurat_clusters' column. Answer format: a single label (shape: label).
# Answer: 5
#
# Task 2
# Description: Identify the seurat_clusters label (numeric cluster identifier) that exhibits the highest proportion of MYCN-amplified cells (MYCN_Status == 'AMP') among all clusters. Answer format: a single integer label (shape: label).
# Answer: 4
#
# Task 3
# Description: Identify the seurat_cluster (label) that exhibits the highest average expression of the MYCN oncogene across all cells in the dataset. Use the 'seurat_clusters' annotation and the expression matrix. Answer format: a single cluster label as a string (e.g., '4'), shape: label.
# Answer: 4
#
# Task 4
# Description: Within the snRNA‑seq dataset, cells are assigned to six Seurat clusters (0‑5). Considering only the cells in cluster 0, compute the average expression of the gene MYCN for each distinct value in the 'Treatment' metadata column. Identify the treatment that yields the highest mean MYCN expression. Answer format: a single label matching exactly the treatment string as it appears in adata.obs['Treatment'] (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 5
# Description: Using the provided snRNA‑seq dataset of neoplastic cells, compute the average expression of the oncogene MYCN (gene symbol) in diagnostic (Stage_Code == "DX") cells and in each post‑treatment (Stage_Code == "PTX") regimen. For each post‑treatment regimen, calculate the log2‑fold‑change of the mean MYCN expression relative to the diagnostic mean (add a small epsilon = 1e‑6 to avoid division by zero). Identify the post‑treatment regimen with the largest positive log2‑fold‑change. Report the exact treatment name as it appears in the 'Treatment' column. Answer format: a single label (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 6
# Description: Among the malignant neuroblast cells (cell_type == 'neuroblast (sensu Vertebrata)' and malignancy == 'Malignant'), compute the average expression of the oncogene MYCN for each Treatment group. Identify the Treatment label with the highest average MYCN expression. Answer format: a single treatment label string exactly as it appears in the data (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 7
# Description: Identify the treatment condition (as listed in the 'Treatment' column of the provided AnnData object) that exhibits the highest average normalized expression of the gene MYCN across all cells. Provide the answer as a single exact label string (shape: label), matching the Treatment entry case‑sensitively and without extra spaces.
# Answer: ANBL12P1-like chemotherapy
#
# Task 8
# Description: Within the neuroblastoma cells (cell_type == 'neuroblast (sensu Vertebrata)') in the provided dataset, compute the average raw count expression of the oncogene MYCN for each distinct Treatment group. Return the Treatment name that yields the highest average MYCN expression. Answer format: a single label exactly matching the Treatment string (shape: label).
# Answer: ANBL12P1-like chemotherapy
#
# Task 9
# Description: Identify the Treatment group that has the highest proportion of cells labeled as 'MES' in the 'cell_state' column of the provided AnnData object. Answer format: a single Treatment label exactly as it appears in the data (shape: label).
# Answer: CHP667
#
# Task 10
# Description: Using the provided snRNA-seq dataset of high-risk neuroblastoma (dataset2.h5ad), consider only cells annotated as neuroblast (cell_type == "neuroblast (sensu Vertebrata)"). For each treatment stage (Stage_Code) – diagnosis (DX) and post‑chemotherapy (PTX) – compute the proportion of cells belonging to each cell_state. Identify the cell_state that shows the greatest positive change in proportion when comparing PTX to DX (i.e., PTX proportion minus DX proportion). Answer format: a single label exactly matching the cell_state name (shape: label).
# Answer: ADRN-Calcium
#
# Task 11
# Description: Using the snRNA‑seq AnnData file at /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset2.h5ad, classify each cell into a 'baseline' or 'post' treatment group based on its 'Treatment' annotation (case‑insensitive): label as 'baseline' if the string contains any of the substrings "primary", "pre", "baseline", or "dx"; label as 'post' if the string contains any of "post", "after", or "resection". Exclude cells that are not assigned to either group. For each value of the column 'seurat_clusters', compute the fraction of cells that are baseline and the fraction that are post. Identify the cluster with the greatest absolute difference between its baseline fraction and post fraction. Return the identifier of that cluster as a single label (shape: label).
# Answer: 2
#
# Task 12
# Description: After Harmony batch correction, compute for each Seurat cluster (adata.obs['seurat_clusters']) the fraction of cells belonging to the most abundant original batch (adata.obs['orig.ident']). Identify the cluster with the highest such fraction (i.e., the poorest batch mixing). Answer format: a single cluster label as a string (shape: label).
# Answer: 2
#
# Task 13
# Description: Within the malignant neuroblast cells (cell_type == 'neuroblast (sensu Vertebrata)'), compare the two treatment groups: 'ANBL12P1-like' (pre‑chemotherapy) and 'ANBL12P1-like chemotherapy' (post‑chemotherapy). Perform a differential expression analysis using Scanpy's rank_genes_groups with method='t-test' on the existing normalized expression matrix (use_raw=False). Identify the gene with the highest positive log2‑fold‑change (most up‑regulated in the post‑chemotherapy group). Provide the answer as a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: ZIC2
#
# Task 14
# Description: In the provided snRNA‑seq dataset, use the binary metadata column **MYCN_Status** (values: 'AMP' and 'NON') as the grouping variable. Identify the gene that has the highest value in the column `vf_vst_counts_variance.standardized` among all genes with a non‑missing `gene_name`. For each distinct `cell_type`, compute the average expression of this gene in the 'AMP' and 'NON' groups, then calculate the log2 fold‑change (NON over AMP) adding a small epsilon (1e‑6) to avoid division by zero. Return the **cell_type** that shows the largest positive log2 fold‑change. Answer format: a single lowercase label with underscores (shape: label).
# Answer: fibroblast
#
# Task 15
# Description: Using the provided snRNA‑seq dataset, restrict analysis to cells annotated as "neuroblast (sensu Vertebrata)". Compare the two treatment stages indicated by the column 'Stage_Code' (DX = pre‑treatment, PTX = post‑chemotherapy). Perform a Wilcoxon rank‑sum differential expression test between PTX and DX groups and identify the gene with the highest positive log₂ fold‑change (most up‑regulated in PTX). Return the gene symbol as a single uppercase HGNC symbol. Answer format: a single gene symbol (shape: gene_symbol).
# Answer: NRG1
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper2/data/dataset3.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: In the snRNA-seq dataset of macrophages from high‑risk neuroblastoma before (DX) and after (PTX) chemotherapy, identify the gene that shows the strongest statistically significant up‑regulation (largest positive log₂ fold‑change, FDR < 0.05) in post‑treatment macrophages compared to diagnostic macrophages. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: PAEP
#
# Task 1
# Description: Using the provided snRNA‑seq dataset of macrophages, perform a differential expression analysis between post‑chemotherapy (Stage_Code = PTX) and pre‑chemotherapy (Stage_Code = DX) cells **within each Seurat cluster** (seurat_clusters). For each cluster, count the number of genes that are significantly up‑regulated in PTX compared to DX, defined as adjusted p‑value < 0.05 and log2 fold‑change > 0.5 (t‑test). Identify the cluster with the **largest** such count. Answer format: a single integer label corresponding to the Seurat cluster identifier (shape: label).
# Answer: 4
#
# Task 2
# Description: Within the most abundant seurat cluster of macrophage nuclei, perform differential expression between the post‑treatment (PTX) and diagnosis (DX) groups. Identify the gene that is most significantly up‑regulated in PTX versus DX (i.e., the up‑regulated gene with the smallest Benjamini‑Hochberg adjusted p‑value). Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: MT-CO3
#
# Task 3
# Description: Using the provided snRNA‑seq dataset of macrophages, compute the proportion of cells belonging to each 'global_cluster' within the diagnostic stage (Stage_Code = 'DX') and the post‑treatment stage (Stage_Code = 'PTX'). Calculate the fold‑change as (PTX proportion + 1e‑6) / (DX proportion + 1e‑6). Identify the cluster with the highest fold‑change (i.e., the greatest increase in relative abundance after treatment). Answer format: a single label string exactly matching the 'global_cluster' identifier (shape: label).
# Answer: 13
#
# Task 4
# Description: Using the provided single-nucleus RNA‑seq dataset of macrophages, compute the average expression of the canonical macrophage marker gene CD68 (Ensembl ID ENSG00000129226) across each distinct value of the 'Treatment' column (the expression matrix is already Harmony‑corrected). Return the exact Treatment label that shows the highest mean CD68 expression. Answer format: a single label (shape: label).
# Answer: CHP667, inc doxorubicin
#
# Task 5
# Description: From the provided snRNA‑seq dataset of macrophages in high‑risk neuroblastoma, cells have been assigned to Seurat clusters (seurat_clusters) and annotated with treatment response categories (Response: Complete, Partial, Progressive, Stable Disease). Identify the Seurat cluster (label as it appears in the seurat_clusters column) that shows the highest enrichment for the 'Complete' response relative to its overall frequency in the dataset. Enrichment is defined as (proportion of 'Complete' cells within the cluster) divided by (overall proportion of 'Complete' cells across all cells). Answer format: a single integer label (shape: label).
# Answer: 3
#
# Task 6
# Description: Among the macrophage cells in the dataset, first exclude any samples (orig.ident) that contain fewer than 50 cells. Then compute the median `phagocytosis_score1` for each remaining Treatment group. Which Treatment has the highest median `phagocytosis_score1`? Answer format: the exact Treatment string as it appears in the `Treatment` column (shape: label).
# Answer: ANBL 09P1
#
# Task 7
# Description: Identify the Treatment group (value in the 'Treatment' column) whose macrophage nuclei have the highest average phagocytosis_score1. Answer format: a single treatment label exactly as it appears in the Treatment column (shape: label).
# Answer: ANBL 09P1
#
# Task 8
# Description: Among the macrophage cells, which Treatment has the highest proportion of cells with Response == "Complete"? If multiple treatments share the maximal proportion, return the alphabetically first one. Answer format: a single treatment name (shape: label).
# Answer: ANBL0532-like therapy with cisplatin & etoposide
#
# Task 9
# Description: From the 'Treatment' column, identify the treatment that exhibits the highest fraction of cells labeled as 'Complete' in the 'Response' column, considering only treatments that have at least 5 cells. If multiple treatments share the highest fraction, select the one that comes first alphabetically. Answer format: a single label (exact treatment string) (shape: label).
# Answer: ANBL0532-like therapy with cisplatin & etoposide
#
# Task 10
# Description: Using the provided snRNA‑seq dataset of macrophages (dataset3.h5ad), determine which treatment group exhibits the highest average expression of the gene that is most up‑regulated between PTX and DX stages (the top gene from a Wilcoxon DE analysis). Report the treatment name exactly as it appears in the 'Treatment' column. Answer format: a single label (shape: label).
# Answer: primary tumor resection + laparotomy post 3 cycles of induction chemo per ANBL12P1
#
# Task 11
# Description: Identify the gene that exhibits the highest positive log2 fold-change when comparing post‑treatment (PTX) macrophage samples to diagnostic (DX) macrophage samples in the provided snRNA‑seq dataset. Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: MT3
#
# Task 12
# Description: Identify the treatment (value in the 'Treatment' column) that contains the largest number of cells annotated as 'Complete' in the 'Response' column. Answer format: a single treatment name (shape: label).
# Answer: ANBL12P1-like
#
# Task 13
# Description: Using the provided AnnData object, identify the donor that exhibits the strongest residual batch effect within the most abundant macrophage sub‑cluster. Follow these exact steps: 1) Subset cells whose 'cell_type' annotation contains the word "macrophage" (case‑insensitive). 2) Determine the most abundant sub‑cluster using the column 'RNA_snn_res.0.2' (if absent, use 'seurat_clusters'); select the cluster with the highest cell count. 3) For cells in that cluster, compute the batch‑mixing LISI (Local Inverse Simpson Index) on the Harmony embedding stored in 'X_harmony' as follows: - Use Euclidean distance to find each cell's 30 nearest neighbors (exclude the cell itself). - For each cell, calculate the proportion of neighbors from each donor (column 'donor_id'), compute the Simpson index (sum of squared proportions), then take its inverse to obtain the LISI value for that cell. - Average LISI values across all cells belonging to each donor. 4) Report the donor ID (value of 'donor_id') with the lowest mean LISI (i.e., poorest mixing). Answer format: a single label (exact donor_id string).
# Answer: CH_18
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Using the provided single‑cell dataset, compute the proportion of each cell type within the Control group and within all disease groups combined (any Condition not equal to 'Control'). Calculate the log2 fold‑change of disease proportion over control proportion for each cell type (add a pseudocount of 1e-6 to avoid division by zero). Identify the cell type with the highest log2 fold‑change. Answer format: a single cell‑type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: lymphocyte
#
# Task 1
# Description: Compute the proportion of each cell type (from the 'cell_type' column) within each condition in the dataset. Then calculate the fold‑change of the proportion in the 'MIS-C' condition relative to the 'Control' condition (MIS-C proportion divided by Control proportion). Identify the cell type with the highest fold‑change. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (case‑sensitive, shape: label).
# Answer: lymphocyte
#
# Task 2
# Description: Using the provided AnnData object, compute for each cell type the proportion of cells belonging to the disease 'myocarditis' and the proportion belonging to 'healthy'. Calculate the log2 fold‑change of these proportions (log2(prop_myocarditis / prop_healthy)) for each cell type. Identify the cell type with the highest positive log2 fold‑change (i.e., the strongest enrichment in myocarditis relative to healthy). Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: lymphocyte
#
# Task 3
# Description: Identify the cell type that shows the largest average absolute difference in log‑transformed expression between the Control and Post‑COVID‑19 conditions. Use the raw UMI counts, apply log1p to non‑zero entries only, compute the mean log expression per gene for each condition within each cell type (requiring at least 20 cells in both conditions), then calculate the average of the absolute differences across all genes. Return the cell‑type name as a single lowercase label with underscores (shape: label).
# Answer: cardiac_endothelial_cell
#
# Task 4
# Description: Using the provided single‑cell RNA‑seq dataset, compute the proportion of each cell type (as given in the 'author_cell_type' column) within the Control and Post‑COVID‑19 conditions. Calculate the log2 fold‑change of these proportions (log2[(Post‑COVID‑19 proportion + 1e-6) / (Control proportion + 1e-6)]). Identify the cell type with the highest positive log2 fold‑change (i.e., the greatest increase in relative abundance in Post‑COVID‑19 compared to Control). Answer format: a single cell‑type label exactly as it appears in the 'author_cell_type' column (shape: label).
# Answer: PKHD1L1+ EC
#
# Task 5
# Description: Identify the cell type that exhibits the greatest up‑regulation of the chemokine gene CXCL10 when comparing MIS‑C (Multisystem Inflammatory Syndrome in Children) to Control samples. Use the mean expression difference (MIS‑C mean minus Control mean) calculated from the provided normalized expression matrix. Answer format: a single cell‑type label in lowercase with underscores (shape: label).
# Answer: cardiac_neuron
#
# Task 6
# Description: Using the provided scRNA‑seq dataset of human cardiac tissue, compare the MIS‑C condition to the Control condition within each annotated cell type. For each cell type, count the number of genes whose log2 fold‑change (MIS‑C vs Control) exceeds 1 (i.e., at least a two‑fold increase). Identify the cell type with the greatest such count. Answer format: a single cell‑type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: cardiac neuron
#
# Task 7
# Description: Identify the Leiden cluster that shows the strongest enrichment of the MIS-C condition relative to the Control condition, measured as the highest positive log2 fold‑change of the proportion of MIS-C cells over Control cells. Answer format: a single cluster label as a string (shape: label).
# Answer: 20
#
# Task 8
# Description: Using the precomputed differential expression results stored in adata.uns['rank_genes_groups'] (which contain the top 11 genes and their log2 fold‑change values for each Leiden cluster), determine the gene that exhibits the largest absolute log‑fold‑change (|logFC|) across all clusters. Return the gene symbol as a single HGNC uppercase identifier (shape: gene_symbol).
# Answer: CPA3
#
# Task 9
# Description: Identify the cell type (author-provided annotation in the 'cell_type' column) whose Leiden cluster exhibits the highest average log2 fold-change of its top-10 marker genes according to the pre-computed differential expression results stored in adata.uns['rank_genes_groups']. Answer format: a single lowercase label with underscores (shape: label).
# Answer: mural_cell
#
# Task 10
# Description: In the provided AnnData object (path: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad), differential expression results are stored in `adata.uns['rank_genes_groups']`. This object contains a field `names` (a list of tuples, each tuple holding the top 11 marker gene symbols for a DE cluster) and a structured array `scores` (with fields '0'–'10') that provides a numeric score for each corresponding gene in the tuple. For every gene that appears in any of the `names` tuples, compute the average of its scores across all clusters where it is present. Which gene has the highest average score? Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: MYBPC3
#
# Task 11
# Description: Using the AnnData file at /mlbio_scratch/videnovi/papers_BIBA/paper4/data/dataset1.h5ad, consider only cells annotated as "cardiac muscle cell" in the "cell_type" column. From the gene metadata (adata.var), select the five genes with the highest normalized dispersion (the column "dispersions_norm"). For each disease condition ("healthy" and "myocarditis" as recorded in the "disease" column), compute the average of the log‑normalized expression values of these five genes across all selected cells. Which disease condition shows the higher average expression? Answer format: a single label matching exactly one of the values in the "disease" column (e.g., "healthy" or "myocarditis").
# Answer: myocarditis
#
# Task 12
# Description: Using the precomputed differential expression results stored in adata.uns['rank_genes_groups'] (groupby='leiden_02'), compute for each Leiden cluster (0‑10) the mean of the absolute log2‑fold‑change (logFC) of all genes that have an adjusted p‑value < 0.05. Identify the cluster with the highest mean absolute logFC. Answer format: a single label (the cluster identifier) with no spaces (shape: label).
# Answer: 6
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/lymph_dataset.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Identify the cell type that constitutes the highest proportion of cells within the 'MIS-C' condition. Answer format: a single lowercase label with underscores (shape: label).
# Answer: natural_killer_cell
#
# Task 1
# Description: Within the natural killer cell population, identify the gene that shows the strongest statistically significant up‑regulation in the Post‑COVID‑19 condition compared to the Control condition. Perform differential expression using Scanpy's `rank_genes_groups` with the Wilcoxon test (default settings, considering all genes). Report the gene with the smallest adjusted p‑value; if multiple genes share this p‑value, choose the one with the highest log2‑fold‑change. Answer format: a single uppercase HGNC gene symbol (shape: gene_symbol).
# Answer: RAP1GAP2
#
# Task 2
# Description: Among cells annotated as cytotoxic T cell, which Condition shows the highest average expression of the gene CXCL9? Answer format: a single condition name exactly as it appears in the Condition column (shape: label).
# Answer: Control
#
# Task 3
# Description: Identify the disease condition that exhibits the highest proportion of the cell type whose proportion across conditions shows the greatest variance. Answer format: a single label exactly matching the condition name as it appears in the 'Condition' column (shape: label).
# Answer: Control
#
# Task 4
# Description: Within the B cell population, identify which experimental condition shows the highest average expression of the cytokine gene CXCL10. Provide the condition name exactly as it appears in the 'Condition' column (case‑sensitive). Answer format: a single label (shape: label).
# Answer: Control
#
# Task 5
# Description: Using the provided single-cell RNA‑seq dataset, compute the average expression of the gene CXCL10 for each cell type within the 'Post-COVID-19' and 'Control' conditions. Calculate the log2 fold‑change (log2[(mean_Post‑COVID‑19 + 1) / (mean_Control + 1)]) for each cell type. Report the cell type that exhibits the highest log2 fold‑change. Answer format: a single cell type label exactly as it appears in the 'cell_type' column of the AnnData object (shape: label).
# Answer: plasma cell
#
# Task 6
# Description: Determine which cell type (as given in the 'author_cell_type' annotation) has the highest proportion of cells from myocarditis samples (disease == 'myocarditis'). Answer format: a single cell‑type label exactly as it appears in the 'author_cell_type' column (shape: label).
# Answer: CD4T_cm
#
# Task 7
# Description: Identify the cell type whose proportion is most increased in myocarditis samples compared to control (normal) samples, using the provided AnnData object. Compute the proportion of each cell type within each disease group, calculate the log2 fold‑change (myocarditis / normal), and select the cell type with the highest positive log2 FC. Answer format: a single label exactly matching the 'cell_type' entry (shape: label).
# Answer: central memory CD4-positive, alpha-beta T cell
#
# Task 8
# Description: Within the effector memory CD8-positive, alpha-beta T cell population, compare cells from the 'Post-COVID-19' condition to those from the 'Control' condition. Perform a standard differential expression analysis (Wilcoxon rank‑sum test) on log‑normalized counts and identify the gene that is significantly up‑regulated in Post‑COVID‑19 (adjusted p‑value < 0.05) with the largest positive log2‑fold‑change. Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: CXCL10
#
# Task 9
# Description: Identify the cell type that shows the greatest proportional enrichment in the Post‑COVID‑19 condition compared to the Control condition. Compute the proportion of each cell type within each condition, calculate the fold‑change (Post‑COVID‑19 proportion divided by Control proportion), and report the cell type with the highest fold‑change. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: cytotoxic T cell
#
# Task 10
# Description: Determine which Condition has the highest proportion of cells annotated as "natural killer cell" in the dataset. Answer format: a single condition label (shape: label).
# Answer: MIS-C
#
# Task 11
# Description: Using the provided single-cell RNA‑seq dataset of human cardiac lymphocytes, consider the cell type annotations in the column 'author_cell_type'. Define NK cells as those labeled 'NK_CD16hi' or 'NK_CD56hi', and define CD8+ T cells as any cell whose annotation starts with 'CD8T_'. For each disease condition (values in the 'Condition' column), compute the average expression of the gene IFNG (interferon‑γ) separately in NK cells and in CD8+ T cells. Then calculate the difference (average IFNG in NK cells minus average IFNG in CD8+ T cells) for each condition. Identify the condition with the largest positive difference (i.e., the strongest relative up‑regulation of IFNG in NK cells compared to CD8+ T cells). Answer format: a single label exactly matching the condition name as it appears in the 'Condition' column (shape: label).
# Answer: MIS-C
#
# Task 12
# Description: Within the cell type "effector memory CD8-positive, alpha-beta T cell", compute the average expression of each gene for the Post-COVID-19 and Control conditions (using the provided AnnData matrix). Calculate the log2 fold change as log2((mean_PostCOVID + 1e-6)/(mean_Control + 1e-6)). Identify the gene with the highest positive log2 fold change. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: MCM8-AS1
#
# Task 13
# Description: Identify the cell type that exhibits the highest number of genes with adjusted p‑value < 0.05 when comparing the Post‑COVID‑19 condition versus the Control condition (using Wilcoxon rank‑sum test on raw counts). Answer format: a single label (shape: label) exactly as it appears in the 'cell_type' column.
# Answer: effector memory CD8-positive, alpha-beta T cell
#
# Task 14
# Description: Using the provided AnnData object, compute for each disease condition (excluding 'Control') the proportional representation of each cell type (using the 'author_cell_type' annotation) relative to the total cells in that condition. Then calculate the fold‑change of each cell‑type proportion versus the corresponding proportion in the 'Control' condition. Identify the condition‑cell_type pair with the highest fold‑change enrichment. Report the answer as a single string formatted as CONDITION::CELL_TYPE (shape: pair).
# Answer: MIS-C::T_prolif
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper4/data/my_dataset.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Identify the cell type that is most enriched in the MIS-C condition relative to the Control condition, using an odds ratio calculated from a 2 × 2 contingency table (add a 0.5 pseudocount to each cell to avoid division by zero). Answer format: a single lowercase label with underscores (shape: label).
# Answer: monocyte
#
# Task 1
# Description: Using the provided AnnData object, calculate the proportion of cells labeled as 'MIS-C' within each coarse cell type found in the 'cell_type' column. Identify the cell type that has the highest proportion of MIS-C cells. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: monocyte
#
# Task 2
# Description: Using the provided AnnData object, calculate for each Condition the proportion of cells annotated as "cycling macrophage" (i.e., number of cycling macrophage cells divided by the total number of cells in that Condition). Identify the Condition with the highest proportion. Answer format: a single condition label exactly as it appears in the 'Condition' column (shape: label).
# Answer: Control
#
# Task 3
# Description: Within the macrophage population, identify the gene that shows the strongest up‑regulation in the MIS‑C condition compared to the Control condition after filtering for genes expressed in ≥10 % of cells in either group. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: NAALADL2
#
# Task 4
# Description: Within the macrophage cell type, identify the gene that exhibits the highest positive log2 fold‑change when comparing myocarditis samples to normal controls. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: CXCL9
#
# Task 5
# Description: Using the precomputed differential expression results stored in adata.uns['rank_genes_groups'], identify the gene among the top 100 DE genes that exhibits the largest positive log2‑fold‑change when comparing myocarditis vs normal samples. Answer format: a single HGNC gene symbol in uppercase (shape: gene_symbol).
# Answer: FP236383.1
#
# Task 6
# Description: Identify the gene with the highest absolute log2 fold change in the differential expression analysis comparing Leiden_12 cluster 0 (reference) versus all other clusters. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: FP236383.1
#
# Task 7
# Description: Within the myeloid subpopulation 'MP_LYVE1hi/MHCII_lo', compute the average log1p‑normalized expression for each gene in the 'MIS-C' condition and in the 'Control' condition. Calculate the log2 fold‑change (log2FC = log2[(mean_MIS‑C + 1e-9)/(mean_Control + 1e-9)]). Identify the gene with the largest positive log2FC. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: KCNE1
#
# Task 8
# Description: From the provided single-cell dataset, consider only cells annotated as 'macrophage' or 'cycling macrophage'. For each Condition, compute the proportion of cells that are labeled 'cycling macrophage' among these selected cells. Identify the Condition with the highest such proportion. Answer format: a single Condition label (shape: label).
# Answer: MIS-C
#
# Task 9
# Description: From the provided single‑cell dataset, compute the proportion of each myeloid cell type (column 'author_cell_type') within the MIS‑C condition and across all cells. Calculate the enrichment ratio for each cell type as (MIS‑C proportion) / (overall proportion), excluding cell types with fewer than 20 cells in the whole dataset. Identify the cell type with the highest enrichment ratio. Answer format: a single label (exact cell type name as it appears in 'author_cell_type').
# Answer: MO_CD16
#
# Task 10
# Description: Identify the cell type (as labeled in the 'author_cell_type' column) that exhibits the highest number of significantly up‑regulated genes (adjusted p‑value < 0.05 and log2 fold‑change > 0) when comparing myocarditis versus normal control samples. Answer format: a single label exactly matching the cell‑type string (shape: label).
# Answer: MP_LYVE1lo/MHCII_hi
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/dataset2.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: From the provided snRNA‑seq dataset of human visceral adipose tissue, compute for each donor (column 'donor_id') the proportion of nuclei annotated as "macrophage" in the 'cell_type' column. Identify the donor with the highest macrophage proportion. Answer format: a single donor identifier (shape: label).
# Answer: 3357
#
# Task 1
# Description: Using the provided snRNA‑seq AnnData object, compute a neighbourhood graph (e.g., Scanpy's default parameters: n_neighbors=15, n_pcs=30 after log‑normalization and HVG selection). For each cell, calculate an integration LISI (iLISI) score based on the 'donor_id' batch variable by measuring the Shannon entropy of donor labels within each cell's neighbourhood and converting it to exp(entropy). Then, average the iLISI scores for each cell type given in the 'cell_type' column. Identify the cell type with the lowest average iLISI (i.e., the most batch‑biased cell type). Answer format: a single cell‑type label (shape: label).
# Answer: B cell
#
# Task 2
# Description: Among all cell types annotated in the dataset (column 'cell_type'), which cell type exhibits the highest average expression of the mitochondrial gene MT-ND1? Answer format: a single lowercase label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: endothelial cell
#
# Task 3
# Description: Using the provided AnnData object, compute the average mitochondrial transcript percentage (percent.mt) for each cell type listed in the 'cell_type' column of adata.obs. Report the cell type that has the highest mean percent.mt. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: endothelial cell
#
# Task 4
# Description: Using the provided snRNA‑seq dataset of human visceral adipose tissue, compute the average log‑normalized expression of the mature adipocyte marker genes ADIPOQ, PLIN1, FABP4 and LPL for each broad cell type annotation (the 'cell_type' column in .obs). Identify the cell type with the highest mean expression across these four markers. Return the cell type label exactly as it appears in the 'cell_type' column. Answer format: a single label (shape: label).
# Answer: adipocyte of omentum tissue
#
# Task 5
# Description: Identify the cell type that shows the highest average raw count expression of the adipogenic master regulator gene PPARG across all cells in the dataset. Report the answer as the exact cell type label found in the 'cell_type' column (case‑sensitive, including spaces). Answer format: a single label (shape: label).
# Answer: adipocyte of omentum tissue
#
# Task 6
# Description: Using the provided snRNA-seq dataset of human visceral adipose tissue, compute the average log‑CP10K expression of the gene PPARG within each annotated cell type (the 'cell_type' column). Normalize raw counts per cell to counts per 10 k, apply log1p, then calculate the mean of this transformed expression for each cell type. Return the cell type with the highest average expression. Answer format: a single cell‑type label exactly as it appears in adata.obs['cell_type'] (shape: label).
# Answer: adipocyte of omentum tissue
#
# Task 7
# Description: For each donor–cell_type combination in the dataset, compute the proportion of that donor's cells among all cells of the given cell_type (i.e., donor‑type count ÷ total count of that cell_type). Identify the donor‑cell_type pair with the highest proportion and report it as a pair formatted exactly as CELLTYPE::DONORID (shape: pair).
# Answer: B cell::3350
#
# Task 8
# Description: Identify the Seurat cluster that has the highest number of macrophage cells among clusters that consist exclusively of macrophages (i.e., 100% macrophage purity). Answer format: a single cluster identifier as a string (shape: label).
# Answer: 3
#
# Task 9
# Description: Identify the donor (donor_id) that contributes the highest proportion of cells annotated as "mesothelial cell" relative to its total number of cells in the dataset. Answer format: a single donor ID string (shape: label).
# Answer: 3313
#
# Task 10
# Description: Using the provided snRNA‑seq AnnData object, identify the cell type that has the highest overall abundance across all cells. Then, among all donors (column 'donor_id'), determine which donor exhibits the highest proportion of that cell type (proportion = cells of that type / total cells for the donor). Answer format: a single donor identifier string (shape: label).
# Answer: 3313
#
# Task 11
# Description: Identify the cell type that exhibits the greatest donor-to-donor variability in median RNA counts (nCount_RNA). For each cell type, compute the median nCount_RNA for each donor, then calculate the coefficient of variation (CV = standard deviation / mean) of those donor‑wise medians (use the population standard deviation, i.e., ddof=0). Report the cell type name exactly as it appears in the 'cell_type' column of the metadata. Answer format: a single label (case‑sensitive).
# Answer: T cell
#
# Dataset: /mlbio_scratch/videnovi/papers_BIBA/paper5/data/VA_adipocytes.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Using the provided single-nucleus RNA‑seq dataset of human visceral adipose tissue adipocytes, compute the average expression of each gene across all cells from male donors and across all cells from female donors. Calculate the log2 fold‑change (male vs female) for each gene, adding a pseudocount of 1e‑6 to avoid division by zero. Identify the gene with the highest positive log2 fold‑change. Answer format: a single gene identifier (uppercase, no spaces), shape: gene_symbol.
# Answer: ENSG00000286009
#
# Task 1
# Description: Identify the donor (donor_id) that exhibits the highest average expression of the adipocyte marker gene ADIPOQ across all its cells in the provided dataset. Answer format: a single donor identifier (shape: label).
# Answer: 3427
#
# Task 2
# Description: Using the provided UMAP embedding (X_umap) for each cell, compute the variance of the UMAP1 and UMAP2 coordinates separately for each donor (column 'donor_id' in .obs). Then calculate the average of these two variances for each donor. Identify the donor with the highest average variance (i.e., the most dispersed cells in the UMAP space). Answer format: a single donor identifier as a label (shape: label).
# Answer: 3427
#
# Task 3
# Description: Perform the following analysis on the AnnData file /mlbio_scratch/videnovi/papers_BIBA/paper5/data/VA_adipocytes.h5ad: (1) normalize raw counts to 10,000 per cell and log1p transform; (2) select the top 2,000 highly variable genes (Seurat flavor); (3) scale the data (max value 10) and compute PCA with 20 components; (4) for each of the first 10 principal components, calculate the proportion of variance explained (PVE) by the donor identifier (donor_id) as the between‑donor sum of squares divided by the total sum of squares; (5) identify the maximum PVE among PCs 1‑10 and report it as a percentage rounded to two decimal places. Answer format: a single numeric value (shape: number).
# Answer: 69.51
#
# Task 4
# Description: From the provided single-nucleus RNA‑seq dataset of human visceral adipose tissue, identify the Seurat cluster (column 'seurat_clusters' in .obs) that exhibits the highest median mitochondrial gene expression percentage (column 'percent.mt'). Report the cluster identifier exactly as it appears (shape: label).
# Answer: 9
#
# Task 5
# ...
# Answer: Tg
#
# Task 7
# Description: For each infection condition (UI, Lm, Pf, Tg) compute the proportion of cells that are annotated with the most abundant cell type identifier CL:3000001. Report the infection label (exact case) that has the highest proportion. Answer format: a single infection label (shape: label).
# Answer: Tg
#
# Task 8
# Description: Identify the infection condition (one of UI, Lm, Tg, Pf) that has the highest proportion of cells belonging to the most abundant cell type across the entire dataset (the cell type with the greatest total cell count). Answer format: a single lowercase label (shape: label).
# Answer: tg
#
# Task 9
# Description: Using the provided placenta scRNA‑seq dataset, consider only the cells collected at 48 hours post‑infection (hpi = '48h'). For each infection condition (values in the 'infection' column: UI, Tg, Pf, Lm), compute the proportion of cells annotated as 'extravillous trophoblast' (cell_type = 'extravillous trophoblast'). Then calculate the fold‑change of each infection's proportion relative to the uninfected control (UI). Report the infection condition that exhibits the highest fold‑change (i.e., the strongest enrichment of extravillous trophoblast at 48 h compared to UI). Answer format: a single infection label (shape: label).
# Answer: Tg
#
# Task 10
# Description: In the dataset, consider only Hofbauer cells sampled at 24 hours post‑infection. For each infection condition (Lm, Tg, Pf) perform a differential expression analysis versus the uninfected (UI) cells using Scanpy's Wilcoxon rank‑sum test (all genes, no preprocessing). Count the number of genes that satisfy adjusted p‑value < 0.05 and log2‑fold‑change > 0.25. Which infection condition has the largest such count? Answer format: a single infection label (one of UI, Lm, Tg, Pf).
# Answer: Pf
#
# Task 11
# Description: In the dataset, consider only the cells annotated as "Hofbauer cell". For each infection condition (UI, Lm, Pf, Tg), compute the average raw (unnormalized) count of the gene IL6 across those Hofbauer cells. Identify the infection condition with the highest mean IL6 expression. Answer format: a single two‑letter label exactly as it appears in the "infection" column (shape: label).
# Answer: Pf
#
# Task 12
# Description: Within the cell type 'Hofbauer cell', determine which infection condition ('UI', 'Tg', 'Pf', or 'Lm') exhibits the highest average expression of the gene CXCL10. Report the answer as the exact infection label (case-sensitive) with shape: label.
# Answer: Pf
#
# Task 13
# Description: From the provided placenta infection scRNA‑seq dataset, compute for each cell type the proportion of cells in each infection condition (UI, Lm, Pf, Tg). For each infected condition (Lm, Pf, Tg) calculate the enrichment as (proportion in infected) / (proportion in UI). Identify the cell‑type and infection condition pair with the maximal enrichment value (exclude UI). Return the answer as a pair formatted as CELLTYPE::INFECTION (exact cell‑type label as in the 'cell_type' column, infection label as in the 'infection' column).
# Answer: Hofbauer cell::Tg
#
# Task 14
# Description: Identify the cell type that exhibits the greatest enrichment (highest fold change of proportion) in Plasmodium falciparum (Pf) infected samples compared to uninfected (UI) samples at the 24 hour time point. Answer format: a single lowercase label without spaces (shape: label).
# Answer: fibroblast
#
# Dataset: /mlbio_scratch/panigrah/agents/data/cell/paper3/data.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Within the scRNA‑seq dataset of mouse barrel cortex, consider only cells annotated with the cluster_name "Baseline". Perform a differential expression analysis comparing the two experimental conditions (Deprived vs Control) using a Wilcoxon rank‑sum test on log‑normalized counts. Identify the gene that is significantly up‑regulated in the Deprived condition (adjusted p‑value < 0.05) and shows the largest positive log2 fold‑change. Provide the answer as a single HGNC gene symbol (shape: gene_symbol).
# Answer: Uba52
#
# Task 1
# Description: Using the provided scRNA‑seq dataset, compute the proportion of cells belonging to each transcriptionally defined cluster (column 'cluster_name') within each experimental condition ('Control' and 'Deprived'). Calculate the log2 fold‑change of the Deprived proportion over the Control proportion for every cluster (add a tiny epsilon = 1e‑6 to avoid division by zero). Report the exact cluster name that exhibits the highest positive log2 fold‑change (i.e., the greatest enrichment in the Deprived condition). Answer format: a single label (case‑preserved cluster name).
# Answer: Interferon-response
#
# Task 2
# Description: Determine which cell cluster (as labeled in the 'cluster_name' column) exhibits the greatest absolute change in its proportion of cells between the 'Control' and 'Deprived' experimental conditions. Report the cluster name exactly as it appears (case‑sensitive, including hyphens and spaces). Answer format: a single label (shape: label).
# Answer: Interferon-response
#
# Task 3
# Description: Using the provided scRNA‑seq AnnData object (data.h5ad), perform a log‑normalization (log1p) of the raw counts, then compute the average expression of each gene across cells in the two experimental conditions (Control vs Deprived). Calculate the log2 fold‑change (log2FC) for each gene as log2((mean_Deprived + 1e-6) / (mean_Control + 1e-6)). Identify the gene with the largest positive log2FC (i.e., most up‑regulated in the Deprived condition). Answer format: a single mouse gene symbol (shape: gene_symbol).
# Answer: 6720483E21Rik
#
# Task 4
# Description: Using the provided scRNA‑seq dataset of mouse barrel cortex microglia, normalize the raw counts to 10,000 per cell and apply log1p transformation. Then perform differential expression between the 'Deprived' and 'Control' conditions (Wilcoxon test, grouping by the 'condition' column). Report the official gene symbol of the gene with the highest positive log2 fold‑change (i.e., the most up‑regulated gene in the Deprived condition). Answer format: a single gene symbol (shape: gene_symbol).
# Answer: 6720483E21Rik
#
# Task 5
# Description: Using the provided scRNA‑seq dataset, compute the enrichment of each transcriptional cluster (column 'final_clusters') in the 'Deprived' condition relative to the 'Control' condition. For each cluster, calculate the log2 enrichment ratio: log2[(fraction of Deprived cells in the cluster) / (fraction of Control cells in the cluster)]. Identify the cluster with the highest positive log2 enrichment (i.e., most over‑represented in Deprived). Answer format: a single cluster label as it appears in 'final_clusters' (shape: label).
# Answer: 8
#
# Task 6
# Description: Consider the provided mouse barrel-cortex scRNA‑seq dataset. Identify the cell type that contains the largest number of cells among those with at least 200 cells. Using the PCA embedding stored in `adata.obsm['X_pca']` (or compute PCA if missing), calculate the integrated Local Inverse Simpson’s Index (iLISI) for each donor (`donor_id`) within this cell type (using 30 nearest neighbours in PCA space). Report the donor identifier that has the lowest average iLISI value. Answer format: a single donor identifier exactly as it appears in `adata.obs['donor_id']` (shape: label).
# Answer: pooled_Deprived_P7
#
# Task 7
# Description: Using the provided single-cell RNA‑seq dataset of mouse barrel cortex microglia, perform differential expression analysis between the 'Deprived' and 'Control' conditions within each subcluster defined by the 'cluster_name' annotation. For each subcluster, count the number of genes that are significantly up‑regulated in the Deprived condition (log2 fold‑change > 0.5 and Benjamini‑Hochberg adjusted p‑value < 0.05). Identify the subcluster with the highest such count. Answer format: a single label matching exactly one of the 'cluster_name' values (shape: label).
# Answer: G1/M Phase early
#
# Task 8
# Description: Identify the mouse gene that shows the strongest up‑regulation (largest positive log2 fold‑change) in microglial cells from the 'Deprived' condition compared to the 'Control' condition, after log‑normalising the raw counts (CP10K) and performing differential expression using the Wilcoxon rank‑sum test (no subsampling). Answer format: a single gene symbol in title case (shape: gene_symbol).
# Answer: Slfn14
#
# Task 9
# Description: Compare the two experimental conditions (Control vs Deprived) within each cell type present in the dataset. For each cell type, consider only those with at least 30 cells in each condition. Perform differential expression (Wilcoxon rank‑sum) between Deprived (treated) and Control (reference) and identify genes with adjusted p‑value < 0.05 and positive log2 fold‑change. Compute the mean log2 fold‑change of these significantly up‑regulated genes for each qualifying cell type. Return the cell‑type label (exactly as it appears in adata.obs['cell_type']) that shows the largest absolute mean log2 fold‑change. Answer format: a single label (shape: label).
# Answer: microglial cell
#
# Dataset: /mlbio_scratch/panigrah/agents/data/cell/paper5/data.h5ad
# ----------------------------------------------------------------------------------------------------
# Task 0
# Description: Identify the author_cell_type (value in the 'author_cell_type' column of adata.obs) that exhibits the largest number of significantly up‑regulated genes (adjusted p‑value < 0.05 and log2 fold‑change > 0) when comparing cytokine‑treated cells versus no‑cytokine cells using Wilcoxon rank‑sum test. Answer format: a single cell‑type label (shape: label).
# Answer: TOM_VCT
#
# Task 1
# Description: Within the single-cell RNA‑seq dataset of human trophoblast organoids, consider only cells annotated as "extravillous trophoblast". Perform a differential expression analysis comparing the "cytokines" treatment group against the "no_cytokines" control group (using standard library‑size normalization, log‑transformation, and the Wilcoxon rank‑sum test on all genes). Identify the gene that shows the largest positive log2‑fold‑change (i.e., strongest up‑regulation) in the cytokine‑treated cells relative to control. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: CSH1
#
# Task 2
# Description: Within the syncytiotrophoblast cell (SCT) population (author_cell_type == "SCT"), compute the average expression of each gene for cytokine‑treated cells (treatment == "cytokines") and for control cells (treatment == "no_cytokines"). Add a pseudocount of 1 to each average, calculate the log2 fold‑change (log2[(treated+1)/(control+1)]) for every gene, and report the gene symbol (HGNC uppercase) that has the highest positive log2 fold‑change. Answer format: a single gene symbol (shape: gene_symbol).
# Answer: TCHH
#
# Task 3
# Description: Using the provided single-cell RNA‑seq dataset, compare the two experimental conditions in the 'treatment' column ("cytokines" vs "no_cytokines"). For each cell type listed in the 'author_cell_type' column, compute the proportion of cells belonging to that type within each condition, then calculate the log2 fold‑change of the proportion (cytokines / no_cytokines). Identify the cell type with the largest positive log2 fold‑change (i.e., the greatest relative increase after cytokine treatment). Answer format: a single label exactly as it appears in the 'author_cell_type' column (shape: label).
# Answer: EVT_late_3
#
# Task 4
# Description: Using the provided single-cell RNA‑seq AnnData object, first normalize raw counts to 10 000 counts per cell (CP10K) and then apply log1p transformation. For each author‑annotated cell type (column 'author_cell_type'), compute the mean log‑expression of every gene separately in the two treatment groups ('cytokines' and 'no_cytokines'). Calculate the log2‑fold‑change for each gene as the difference of these means (treated minus control). Count, for each cell type, how many genes have log2‑fold‑change greater than 0.25. Report the cell type that has the largest such count. Answer format: a single label exactly as it appears in the 'author_cell_type' column (shape: label).
# Answer: EVT_late_3
#
# Task 5
# Description: For each cell type annotated in the 'cell_type' column, compute the average expression of every gene across cells under the two treatment conditions ('cytokines' and 'no_cytokines'). For each cell type, calculate the log2 fold‑change (log2FC) of each gene between the cytokine‑treated and untreated groups, adding a negligible pseudocount to avoid division by zero. Count how many genes have an absolute log2FC ≥ 1 (i.e., at least a 2‑fold change). Identify the cell type with the largest such gene count. Answer format: a single cell type label exactly as it appears in the 'cell_type' column (shape: label).
# Answer: syncytiotrophoblast cell
#
# Task 6
# Description: Identify the trophoblast cell type that exhibits the strongest treatment‑induced expression change, defined as the largest absolute log2 fold change (log2FC) observed for any gene when comparing cytokine‑treated cells versus no‑cytokine cells (averaged within each cell type). Answer format: a single lowercase label with underscores (shape: label).
# Answer: syncytiotrophoblast_cell
#
# Task 7
# Description: Using the provided single-cell RNA‑seq dataset of human trophoblast organoids, perform differential expression analysis between cytokine‑treated and untreated cells within each broad cell type (syncytiotrophoblast cell, extravillous trophoblast, placental villous trophoblast). Count the number of genes that are significantly up‑regulated in the cytokine condition (adjusted p‑value < 0.05 and log2‑fold‑change > 0.25). Identify the cell type with the greatest number of such up‑regulated genes. Answer format: a single label matching exactly one of the values in the 'cell_type' column (shape: label).
# Answer: extravillous trophoblast
#
# Task 8
# Description: Identify the gene that is most significantly up‑regulated by cytokine treatment within the trophoblast sub‑type 'EVT_proliferating', after accounting for donor variability. Use a Wilcoxon rank‑genes‑groups test per donor, combine p‑values across donors with Fisher's method, average log‑fold‑changes, keep only genes with positive average logFC, apply Benjamini‑Hochberg correction, and report the gene symbol (HGNC uppercase) with the smallest adjusted combined p‑value. Answer format: a single HGNC gene symbol (shape: gene_symbol).
# Answer: CXCL8
#
# Task 9
# Description: Within the VCT cell type (author_cell_type == "VCT"), compute the log2 fold change (log2FC) for each gene between cytokine‑treated cells (treatment == "cytokines") and control cells (treatment == "no_cytokines") using CPM normalization followed by log1p transformation and mean expression per group. Return the HGNC gene symbol (uppercase) of the gene with the highest positive log2FC. Answer format: a single gene_symbol.
# Answer: SRCIN1
#
# Task 10
# Description: Using the provided single‑cell RNA‑seq dataset of human trophoblast organoids, perform a standard scRNA‑seq analysis pipeline (QC filtering, normalization, log‑transformation, selection of the top 3000 highly variable genes, and differential expression testing between the 'cytokines' and 'no_cytokines' treatment groups within each author‑provided cell type). Count the number of genes that are significantly up‑regulated in the cytokine‑treated condition (log2 fold‑change > 0.25 and Benjamini‑Hochberg adjusted p‑value < 0.05). Report the cell‑type label (exactly as it appears in the 'author_cell_type' column) that has the largest number of such up‑regulated genes. Answer format: a single label (shape: label).
# Answer: SCT

# %%
duplicates_by_dataset= {
    # "/mlbio_scratch/panigrah/agents/data/nature/paper2/processed_MuSC_data.h5ad": [[5, 6]],
    # "/mlbio_scratch/panigrah/agents/data/nature/paper2/processed_myonuclei_data.h5ad": [[10, 9]],
    "/mlbio_scratch/panigrah/agents/data/nature/paper6/data.h5ad": [[4, 0, 2]],
    "/mlbio_scratch/panigrah/agents/data/cell/paper2/data.h5ad": [[6, 8]],
    # "/mlbio_scratch/panigrah/agents/data/cell/paper3/data.h5ad": [[3, 8]],
}

# %%
clean_tasks = get_clean_tasks(tasks_by_dataset, duplicates_by_dataset)
print(f"Tasks after dataset-wise filtration: {len(clean_tasks)}")
# Out:
# Tasks after dataset-wise filtration: 283

# %%
clean_tasks_path = tasks_dir / "clean.json"
save_data(clean_tasks, clean_tasks_path)
